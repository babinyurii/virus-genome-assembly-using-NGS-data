# %%
# %%bash
# samtools mpileup --BCF \
# --fasta ./input_data/ref.fasta \
# ./samtools_out/lsdv_51_sorted_rmdup.bam > ./samtools_out/lsdv_51_vars_indels_in.bcf
# Out:
# [fai_load] build FASTA index.
# [mpileup] 1 samples in 1 input files
# <mpileup> Set max per-file depth to 8000

# %%
# %%bash
# bcftools call \
# --consensus-caller \
# --variants-only \
# --ploidy-file ./samtools_out/ploid.txt \
# ./samtools_out/lsdv_51_vars_indels_in.bcf > ./samtools_out/lsdv_51_vars_indels_in.vcf

# %% [markdown]
# #### trying to normalize indels

# %%
# %%bash
# bcftools norm -f ./input_data/ref.fasta ./samtools_out/lsdv_51_vars_indels_in.vcf \
# -o ./samtools_out/lsdv_51_vars_indels_in_norm.vcf
# Out:
# Lines   total/split/realigned/skipped:	43/0/22/0

# %%
from sequman import count_snps, count_indels, vcf_to_df

# %%
help(count_snps)
# Out:
# Help on function count_snps in module sequman:
#
# count_snps(vcf_file, min_depth=10, verbose='True')
#     counts SNPs in vcf file
#     ----------------
#     vcf_file: str
#         input vcf
#     min_depth: int
#         minimum depth in favour of SNPs, 10 by default
#     verbose: bool
#         True - prints information about the variants
#         False - keeps silent

# %%
count_snps("./samtools_out/lsdv_51_vars_indels_in.vcf")
# Out:
# chromosome: MH893760.2, position: 66862, ref: G, snp variant: [A]
# depth at position: 137
# reads supporting reference: 1
# reads supporting snp variant: 133
# ==========================================================================
# chromosome: MH893760.2, position: 73757, ref: A, snp variant: [T]
# depth at position: 82
# reads supporting reference: 0
# reads supporting snp variant: 77
# ==========================================================================
# chromosome: MH893760.2, position: 117638, ref: A, snp variant: [T]
# depth at position: 116
# reads supporting reference: 0
# reads supporting snp variant: 112
# ==========================================================================
# chromosome: MH893760.2, position: 122070, ref: T, snp variant: [C]
# depth at position: 57
# reads supporting reference: 3
# reads supporting snp variant: 48
# ==========================================================================
# chromosome: MH893760.2, position: 122071, ref: C, snp variant: [T]
# depth at position: 57
# reads supporting reference: 7
# reads supporting snp variant: 48
# ==========================================================================
# chromosome: MH893760.2, position: 135500, ref: A, snp variant: [T]
# depth at position: 54
# reads supporting reference: 0
# reads supporting snp variant: 53
# ==========================================================================
# chromosome: MH893760.2, position: 145320, ref: C, snp variant: [T]
# depth at position: 136
# reads supporting reference: 0
# reads supporting snp variant: 132
# ==========================================================================
# chromosome: MH893760.2, position: 145323, ref: G, snp variant: [T]
# depth at position: 138
# reads supporting reference: 0
# reads supporting snp variant: 132
# ==========================================================================
# chromosome: MH893760.2, position: 145333, ref: G, snp variant: [T]
# depth at position: 140
# reads supporting reference: 0
# reads supporting snp variant: 137
# ==========================================================================
# chromosome: MH893760.2, position: 145339, ref: G, snp variant: [T]
# depth at position: 141
# reads supporting reference: 0
# reads supporting snp variant: 140
# ==========================================================================
# chromosome: MH893760.2, position: 146672, ref: G, snp variant: [A]
# depth at position: 72
# reads supporting reference: 0
# reads supporting snp variant: 68
# ==========================================================================
# chromosome: MH893760.2, position: 146675, ref: G, snp variant: [T]
# depth at position: 72
# reads supporting reference: 0
# reads supporting snp variant: 68
# ==========================================================================
# chromosome: MH893760.2, position: 146678, ref: C, snp variant: [A]
# depth at position: 72
# reads supporting reference: 0
# reads supporting snp variant: 67
# ==========================================================================
# chromosome: MH893760.2, position: 146778, ref: T, snp variant: [A]
# depth at position: 65
# reads supporting reference: 0
# reads supporting snp variant: 60
# ==========================================================================
# chromosome: MH893760.2, position: 148234, ref: A, snp variant: [G]
# depth at position: 70
# reads supporting reference: 0
# reads supporting snp variant: 63
# ==========================================================================
# chromosome: MH893760.2, position: 148242, ref: A, snp variant: [T]
# depth at position: 72
# reads supporting reference: 0
# reads supporting snp variant: 63
# ==========================================================================
# chromosome: MH893760.2, position: 148250, ref: G, snp variant: [T]
# depth at position: 72
# reads supporting reference: 0
# reads supporting snp variant: 68
# ==========================================================================
# total number of SNPs 17
# 0

# %%
count_indels("./samtools_out/lsdv_51_vars_indels_in.vcf")
# Out:
# chromosome: MH893760.2, position: 4802, ref: GTTTTTTTTT, indel variant: [GTTTTTTTT]
# depth at position: 96
# reads supporting reference: 0
# reads supporting indel variant: 85
# ==========================================================================
# chromosome: MH893760.2, position: 10739, ref: ATTTTTTTTTT, indel variant: [ATTTTTTTTTTT]
# depth at position: 94
# reads supporting reference: 1
# reads supporting indel variant: 80
# ==========================================================================
# chromosome: MH893760.2, position: 11566, ref: TTTATTAT, indel variant: [TTTAT]
# depth at position: 118
# reads supporting reference: 0
# reads supporting indel variant: 113
# ==========================================================================
# chromosome: MH893760.2, position: 11571, ref: TATAA, indel variant: [TA]
# depth at position: 120
# reads supporting reference: 2
# reads supporting indel variant: 107
# ==========================================================================
# chromosome: MH893760.2, position: 12055, ref: TTGT, indel variant: [TTGTGT]
# depth at position: 117
# reads supporting reference: 5
# reads supporting indel variant: 58
# ==========================================================================
# chromosome: MH893760.2, position: 12057, ref: GTTTTTTTTTTT, indel variant: [GTTTTTTTTTTTTT, GTTTTTTTTTTTTTT]
# depth at position: 116
# reads supporting reference: 0
# reads supporting indel variant: 98
# ==========================================================================
# chromosome: MH893760.2, position: 16010, ref: TAAAAAAAAA, indel variant: [TAAAAAAAAAA]
# depth at position: 89
# reads supporting reference: 1
# reads supporting indel variant: 80
# ==========================================================================
# chromosome: MH893760.2, position: 18168, ref: CTTTTTTTT, indel variant: [CTTTTTTT]
# depth at position: 72
# reads supporting reference: 0
# reads supporting indel variant: 66
# ==========================================================================
# chromosome: MH893760.2, position: 27951, ref: ATTTTTTTTTTT, indel variant: [ATTTTTTTTTTTT, ATTTTTTTTTTTTT]
# depth at position: 126
# reads supporting reference: 0
# reads supporting indel variant: 110
# ==========================================================================
# chromosome: MH893760.2, position: 40202, ref: ATTTTTTT, indel variant: [ATTTTTT]
# depth at position: 84
# reads supporting reference: 0
# reads supporting indel variant: 75
# ==========================================================================
# chromosome: MH893760.2, position: 57346, ref: CAAAAAAAA, indel variant: [CAAAAAAAAA, CAAAAAAAAAA]
# depth at position: 88
# reads supporting reference: 0
# reads supporting indel variant: 80
# ==========================================================================
# chromosome: MH893760.2, position: 57906, ref: AGCG, indel variant: [A]
# depth at position: 110
# reads supporting reference: 3
# reads supporting indel variant: 51
# ==========================================================================
# chromosome: MH893760.2, position: 57907, ref: GCGACGACGA, indel variant: [GCGACGA]
# depth at position: 105
# reads supporting reference: 0
# reads supporting indel variant: 69
# ==========================================================================
# chromosome: MH893760.2, position: 57914, ref: CGATGATGAT, indel variant: [CGATGAT]
# depth at position: 110
# reads supporting reference: 2
# reads supporting indel variant: 56
# ==========================================================================
# chromosome: MH893760.2, position: 57992, ref: ATTTTTTTT, indel variant: [ATTTTTTTTT]
# depth at position: 103
# reads supporting reference: 0
# reads supporting indel variant: 74
# ==========================================================================
# chromosome: MH893760.2, position: 84130, ref: ATTTTT, indel variant: [ATTTTTT]
# depth at position: 148
# reads supporting reference: 0
# reads supporting indel variant: 144
# ==========================================================================
# chromosome: MH893760.2, position: 89921, ref: TGAAGAAGAAGAAGAAGAAGAAGAA, indel variant: [TGAAGAAGAAGAAGAAGAAGAA]
# depth at position: 149
# reads supporting reference: 0
# reads supporting indel variant: 121
# ==========================================================================
# chromosome: MH893760.2, position: 99158, ref: ATTTTTTTTT, indel variant: [ATTTTTTTTTT]
# depth at position: 64
# reads supporting reference: 0
# reads supporting indel variant: 63
# ==========================================================================
# chromosome: MH893760.2, position: 135383, ref: ATTTTTTT, indel variant: [ATTTTTTTT]
# depth at position: 51
# reads supporting reference: 0
# reads supporting indel variant: 42
# ==========================================================================
# chromosome: MH893760.2, position: 137166, ref: GTTTTTTT, indel variant: [GTTTTTTTT, GTTTTTTTTT]
# depth at position: 171
# reads supporting reference: 0
# reads supporting indel variant: 158
# ==========================================================================
# chromosome: MH893760.2, position: 140550, ref: AAAAAAAAA, indel variant: [AAAAAAAAAAAAAA]
# depth at position: 163
# reads supporting reference: 0
# reads supporting indel variant: 132
# ==========================================================================
# chromosome: MH893760.2, position: 140558, ref: A, indel variant: [AAAAAAT]
# depth at position: 167
# reads supporting reference: 7
# reads supporting indel variant: 115
# ==========================================================================
# chromosome: MH893760.2, position: 145023, ref: GAAAAAAA, indel variant: [GAAAAAA]
# depth at position: 129
# reads supporting reference: 0
# reads supporting indel variant: 120
# ==========================================================================
# chromosome: MH893760.2, position: 145762, ref: AAATAATAATAATA, indel variant: [AAATAATAATAATAATA]
# depth at position: 92
# reads supporting reference: 0
# reads supporting indel variant: 87
# ==========================================================================
# chromosome: MH893760.2, position: 146705, ref: CN, indel variant: [C]
# depth at position: 61
# reads supporting reference: 0
# reads supporting indel variant: 52
# ==========================================================================
# total number of indels 25
# 0

# %%
df = vcf_to_df("./samtools_out/lsdv_51_vars_indels_in.vcf", var_type="snp")

# %%
df.to_excel("./samtools_out/lsdv_51_snps.xlsx")

# %%
df_indels = vcf_to_df("./samtools_out/lsdv_51_vars_indels_in.vcf", var_type="indel")

# %%
df_indels.to_excel("./samtools_out/lsdv_51_indels.xlsx")

# %%
import vcf

# %%
vcf_reader = vcf.Reader(open('./samtools_out/lsdv_51_vars_indels_in.vcf', 'r'))
counter = 0
for record in vcf_reader:
   
    print(record)
    print(record.CHROM)
    print(record.INFO["DP"])
    print(record.INFO["DP4"])
    print(record.INFO)
    print("--------------------")
    counter += 1

print(counter)
# Out:
# Record(CHROM=MH893760.2, POS=4802, REF=GTTTTTTTTT, ALT=[GTTTTTTTT])
# MH893760.2
# 96
# [0, 0, 34, 51]
# {'INDEL': True, 'IDV': 88, 'IMF': 0.916667, 'DP': 96, 'VDB': 0.666497, 'SGB': -0.693147, 'MQSB': 0.625439, 'MQ0F': 0.0208333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 34, 51], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=10739, REF=ATTTTTTTTTT, ALT=[ATTTTTTTTTTT])
# MH893760.2
# 94
# [1, 0, 40, 40]
# {'INDEL': True, 'IDV': 82, 'IMF': 0.87234, 'DP': 94, 'VDB': 0.900269, 'SGB': -0.693147, 'MQSB': 0.922574, 'MQ0F': 0.0106383, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 40, 40], 'MQ': 42, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.435685, 0.310837]}
# --------------------
# Record(CHROM=MH893760.2, POS=11566, REF=TTTATTAT, ALT=[TTTAT])
# MH893760.2
# 118
# [0, 0, 41, 72]
# {'INDEL': True, 'IDV': 111, 'IMF': 0.940678, 'DP': 118, 'VDB': 0.0807615, 'SGB': -0.693147, 'MQSB': 0.888318, 'MQ0F': 0.0254237, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 41, 72], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=11571, REF=TATAA, ALT=[TA])
# MH893760.2
# 120
# [1, 1, 40, 67]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00833333, 'DP': 120, 'VDB': 0.0137283, 'SGB': -0.693147, 'MQSB': 0.899702, 'MQ0F': 0.025, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 1, 40, 67], 'MQ': 41, 'FQ': -999.0, 'PV4': [1.0, 2.93656e-05, 0.365937, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=12055, REF=TTGT, ALT=[TTGTGT])
# MH893760.2
# 117
# [3, 2, 20, 38]
# {'INDEL': True, 'IDV': 4, 'IMF': 0.034188, 'DP': 117, 'VDB': 0.194602, 'SGB': -0.693147, 'MQSB': 0.999363, 'MQ0F': 0.0512821, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [3, 2, 20, 38], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.345325, 3.67989e-05, 0.306071, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=12057, REF=GTTTTTTTTTTT, ALT=[GTTTTTTTTTTTTT, GTTTTTTTTTTTTTT])
# MH893760.2
# 116
# [0, 0, 51, 47]
# {'INDEL': True, 'IDV': 99, 'IMF': 0.853448, 'DP': 116, 'VDB': 0.20465, 'SGB': -0.693147, 'MQSB': 0.4651, 'MQ0F': 0.0517241, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 51, 47], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=16010, REF=TAAAAAAAAA, ALT=[TAAAAAAAAAA])
# MH893760.2
# 89
# [0, 1, 46, 34]
# {'INDEL': True, 'IDV': 77, 'IMF': 0.865169, 'DP': 89, 'VDB': 0.726075, 'SGB': -0.693147, 'MQSB': 0.998626, 'MQ0F': 0.011236, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 46, 34], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.432099, 1.0, 0.412569, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=18168, REF=CTTTTTTTT, ALT=[CTTTTTTT])
# MH893760.2
# 72
# [0, 0, 34, 32]
# {'INDEL': True, 'IDV': 68, 'IMF': 0.931507, 'DP': 72, 'VDB': 0.57387, 'SGB': -0.693147, 'MQSB': 0.995975, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 34, 32], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=27951, REF=ATTTTTTTTTTT, ALT=[ATTTTTTTTTTTT, ATTTTTTTTTTTTT])
# MH893760.2
# 126
# [0, 0, 52, 58]
# {'INDEL': True, 'IDV': 108, 'IMF': 0.857143, 'DP': 126, 'VDB': 0.709823, 'SGB': -0.693147, 'MQSB': 0.85354, 'MQ0F': 0.031746, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 52, 58], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=40202, REF=ATTTTTTT, ALT=[ATTTTTT])
# MH893760.2
# 84
# [0, 0, 36, 39]
# {'INDEL': True, 'IDV': 77, 'IMF': 0.916667, 'DP': 84, 'VDB': 0.510574, 'SGB': -0.693147, 'MQSB': 0.940602, 'MQ0F': 0.0357143, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 36, 39], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=57346, REF=CAAAAAAAA, ALT=[CAAAAAAAAA, CAAAAAAAAAA])
# MH893760.2
# 88
# [0, 0, 43, 37]
# {'INDEL': True, 'IDV': 84, 'IMF': 0.954545, 'DP': 88, 'VDB': 0.858419, 'SGB': -0.693147, 'MQSB': 0.946092, 'MQ0F': 0.0227273, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 43, 37], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=57906, REF=AGCG, ALT=[A])
# MH893760.2
# 110
# [2, 1, 11, 40]
# {'INDEL': True, 'IDV': 5, 'IMF': 0.0454545, 'DP': 110, 'VDB': 0.927753, 'SGB': -0.693147, 'MQSB': 0.478632, 'MQ0F': 0.0909091, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [2, 1, 11, 40], 'MQ': 40, 'FQ': -999.0, 'PV4': [0.140461, 0.180946, 0.276489, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=57907, REF=GCGACGACGA, ALT=[GCGACGA])
# MH893760.2
# 105
# [0, 0, 21, 48]
# {'INDEL': True, 'IDV': 90, 'IMF': 0.818182, 'DP': 105, 'VDB': 0.990754, 'SGB': -0.693147, 'MQSB': 0.205076, 'MQ0F': 0.0952381, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 21, 48], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=57914, REF=CGATGATGAT, ALT=[CGATGAT])
# MH893760.2
# 110
# [0, 2, 15, 41]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00909091, 'DP': 110, 'VDB': 0.999802, 'SGB': -0.693147, 'MQSB': 0.341941, 'MQ0F': 0.0727273, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 2, 15, 41], 'MQ': 40, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.307592, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=57992, REF=ATTTTTTTT, ALT=[ATTTTTTTTT])
# MH893760.2
# 103
# [0, 0, 25, 49]
# {'INDEL': True, 'IDV': 85, 'IMF': 0.825243, 'DP': 103, 'VDB': 0.179295, 'SGB': -0.693147, 'MQSB': 0.970263, 'MQ0F': 0.0776699, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 25, 49], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=66862, REF=G, ALT=[A])
# MH893760.2
# 137
# [1, 0, 64, 69]
# {'DP': 137, 'VDB': 0.870541, 'SGB': -0.693147, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.961432, 'BQB': 1.0, 'MQ0F': 0.0145985, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 64, 69], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.485075, 1.0, 1.0, 0.494593]}
# --------------------
# Record(CHROM=MH893760.2, POS=73757, REF=A, ALT=[T])
# MH893760.2
# 82
# [0, 0, 41, 36]
# {'DP': 82, 'VDB': 0.358369, 'SGB': -0.693147, 'MQSB': 0.884627, 'MQ0F': 0.0121951, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 41, 36], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=84130, REF=ATTTTT, ALT=[ATTTTTT])
# MH893760.2
# 148
# [0, 0, 71, 73]
# {'INDEL': True, 'IDV': 146, 'IMF': 0.986486, 'DP': 148, 'VDB': 0.597936, 'SGB': -0.693147, 'MQSB': 0.999998, 'MQ0F': 0.0135135, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 71, 73], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=89921, REF=TGAAGAAGAAGAAGAAGAAGAAGAA, ALT=[TGAAGAAGAAGAAGAAGAAGAA])
# MH893760.2
# 149
# [0, 0, 56, 65]
# {'INDEL': True, 'IDV': 120, 'IMF': 0.794702, 'DP': 149, 'VDB': 0.134161, 'SGB': -0.693147, 'MQSB': 0.93594, 'MQ0F': 0.0134228, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 56, 65], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=99158, REF=ATTTTTTTTT, ALT=[ATTTTTTTTTT])
# MH893760.2
# 64
# [0, 0, 28, 35]
# {'INDEL': True, 'IDV': 63, 'IMF': 0.984375, 'DP': 64, 'VDB': 0.308308, 'SGB': -0.693147, 'MQSB': 0.768226, 'MQ0F': 0.03125, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 28, 35], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=117638, REF=A, ALT=[T])
# MH893760.2
# 116
# [0, 0, 57, 55]
# {'DP': 116, 'VDB': 0.923069, 'SGB': -0.693147, 'MQSB': 0.897272, 'MQ0F': 0.0258621, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 57, 55], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=122070, REF=T, ALT=[C])
# MH893760.2
# 57
# [2, 1, 27, 21]
# {'DP': 57, 'VDB': 0.261951, 'SGB': -0.693147, 'RPB': 0.0157039, 'MQB': 0.864129, 'MQSB': 1.0, 'BQB': 0.260031, 'MQ0F': 0.0350877, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [2, 1, 27, 21], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.248476, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=122071, REF=C, ALT=[T])
# MH893760.2
# 57
# [4, 3, 27, 21]
# {'DP': 57, 'VDB': 0.271245, 'SGB': -0.693147, 'RPB': 0.986618, 'MQB': 0.728763, 'MQSB': 0.999856, 'BQB': 0.874583, 'MQ0F': 0.0350877, 'AF1': 0.5, 'AC1': 1.0, 'DP4': [4, 3, 27, 21], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 0.312318, 0.149931, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=135383, REF=ATTTTTTT, ALT=[ATTTTTTTT])
# MH893760.2
# 51
# [0, 0, 21, 21]
# {'INDEL': True, 'IDV': 41, 'IMF': 0.803922, 'DP': 51, 'VDB': 0.230443, 'SGB': -0.693146, 'MQSB': 0.549515, 'MQ0F': 0.0784314, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 21, 21], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=135500, REF=A, ALT=[T])
# MH893760.2
# 54
# [0, 0, 37, 16]
# {'DP': 54, 'VDB': 0.265557, 'SGB': -0.693147, 'MQSB': 0.98806, 'MQ0F': 0.0555556, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 37, 16], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=137166, REF=GTTTTTTT, ALT=[GTTTTTTTT, GTTTTTTTTT])
# MH893760.2
# 171
# [0, 0, 74, 84]
# {'INDEL': True, 'IDV': 161, 'IMF': 0.94152, 'DP': 171, 'VDB': 0.203465, 'SGB': -0.693147, 'MQSB': 0.99542, 'MQ0F': 0.0292398, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 74, 84], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=140550, REF=AAAAAAAAA, ALT=[AAAAAAAAAAAAAA])
# MH893760.2
# 163
# [0, 0, 73, 59]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00613497, 'DP': 163, 'VDB': 0.697335, 'SGB': -0.693147, 'MQSB': 0.562151, 'MQ0F': 0.0368098, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 73, 59], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=140558, REF=A, ALT=[AAAAAAT])
# MH893760.2
# 167
# [1, 6, 61, 54]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00598802, 'DP': 167, 'VDB': 0.661128, 'SGB': -0.693147, 'MQSB': 0.34212, 'MQ0F': 0.0359281, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 6, 61, 54], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.0594468, 1.0, 0.227097, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=145023, REF=GAAAAAAA, ALT=[GAAAAAA])
# MH893760.2
# 129
# [0, 0, 47, 73]
# {'INDEL': True, 'IDV': 113, 'IMF': 0.875969, 'DP': 129, 'VDB': 0.757602, 'SGB': -0.693147, 'MQSB': 0.986645, 'MQ0F': 0.00775194, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 47, 73], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145029, REF=AAT, ALT=[A])
# MH893760.2
# 126
# [2, 2, 3, 4]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00793651, 'DP': 126, 'VDB': 1.0, 'SGB': -0.636426, 'MQSB': 0.950952, 'MQ0F': 0.00793651, 'AF1': 0.5, 'AC1': 1.0, 'DP4': [2, 2, 3, 4], 'MQ': 42, 'FQ': -999.0, 'PV4': [1.0, 1.0, 1.0, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=145320, REF=C, ALT=[T])
# MH893760.2
# 136
# [0, 0, 70, 62]
# {'DP': 136, 'VDB': 0.494622, 'SGB': -0.693147, 'MQSB': 0.868421, 'MQ0F': 0.0294118, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 70, 62], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145323, REF=G, ALT=[T])
# MH893760.2
# 138
# [0, 0, 69, 63]
# {'DP': 138, 'VDB': 0.442293, 'SGB': -0.693147, 'MQSB': 0.920232, 'MQ0F': 0.0289855, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 69, 63], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145333, REF=G, ALT=[T])
# MH893760.2
# 140
# [0, 0, 72, 65]
# {'DP': 140, 'VDB': 0.565474, 'SGB': -0.693147, 'MQSB': 0.914641, 'MQ0F': 0.0285714, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 72, 65], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145339, REF=G, ALT=[T])
# MH893760.2
# 141
# [0, 0, 74, 66]
# {'DP': 141, 'VDB': 0.67048, 'SGB': -0.693147, 'MQSB': 0.834712, 'MQ0F': 0.0283688, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 74, 66], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145762, REF=AAATAATAATAATA, ALT=[AAATAATAATAATAATA])
# MH893760.2
# 92
# [0, 0, 43, 44]
# {'INDEL': True, 'IDV': 87, 'IMF': 0.945652, 'DP': 92, 'VDB': 0.253694, 'SGB': -0.693147, 'MQSB': 0.935539, 'MQ0F': 0.0326087, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 43, 44], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146672, REF=G, ALT=[A])
# MH893760.2
# 72
# [0, 0, 28, 40]
# {'DP': 72, 'VDB': 0.751391, 'SGB': -0.693147, 'MQSB': 0.727594, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 28, 40], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146675, REF=G, ALT=[T])
# MH893760.2
# 72
# [0, 0, 29, 39]
# {'DP': 72, 'VDB': 0.819747, 'SGB': -0.693147, 'MQSB': 0.821951, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 29, 39], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146678, REF=C, ALT=[A])
# MH893760.2
# 72
# [0, 0, 29, 38]
# {'DP': 72, 'VDB': 0.79177, 'SGB': -0.693147, 'MQSB': 0.856405, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 29, 38], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146705, REF=CN, ALT=[C])
# MH893760.2
# 61
# [0, 0, 23, 29]
# {'INDEL': True, 'IDV': 53, 'IMF': 0.868852, 'DP': 61, 'VDB': 0.496348, 'SGB': -0.693147, 'MQSB': 0.991718, 'MQ0F': 0.0327869, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 23, 29], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146778, REF=T, ALT=[A])
# MH893760.2
# 65
# [0, 0, 34, 26]
# {'DP': 65, 'VDB': 0.631909, 'SGB': -0.693147, 'MQSB': 0.615893, 'MQ0F': 0.0461538, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 34, 26], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=148234, REF=A, ALT=[G])
# MH893760.2
# 70
# [0, 0, 36, 27]
# {'DP': 70, 'VDB': 0.146847, 'SGB': -0.693147, 'MQSB': 0.623374, 'MQ0F': 0.0571429, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 36, 27], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=148242, REF=A, ALT=[T])
# MH893760.2
# 72
# [0, 0, 36, 27]
# {'DP': 72, 'VDB': 0.151561, 'SGB': -0.693147, 'MQSB': 0.623374, 'MQ0F': 0.0694444, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 36, 27], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=148250, REF=G, ALT=[T])
# MH893760.2
# 72
# [0, 0, 38, 30]
# {'DP': 72, 'VDB': 0.276283, 'SGB': -0.693147, 'MQSB': 0.52434, 'MQ0F': 0.0694444, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 38, 30], 'MQ': 38, 'FQ': -999.0}
# --------------------
# 43

# %%
vcf_reader = vcf.Reader(open('./samtools_out/lsdv_51_vars_indels_in_norm.vcf', 'r'))
counter = 0
for record in vcf_reader:
   
    print(record)
    print(record.INFO["DP"])
    print(record.INFO["DP4"])
    print(record.INFO)
    print("--------------------")
    counter += 1

print(counter)
# Out:
# Record(CHROM=MH893760.2, POS=4802, REF=GT, ALT=[G])
# 96
# [0, 0, 34, 51]
# {'INDEL': True, 'IDV': 88, 'IMF': 0.916667, 'DP': 96, 'VDB': 0.666497, 'SGB': -0.693147, 'MQSB': 0.625439, 'MQ0F': 0.0208333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 34, 51], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=10739, REF=A, ALT=[AT])
# 94
# [1, 0, 40, 40]
# {'INDEL': True, 'IDV': 82, 'IMF': 0.87234, 'DP': 94, 'VDB': 0.900269, 'SGB': -0.693147, 'MQSB': 0.922574, 'MQ0F': 0.0106383, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 40, 40], 'MQ': 42, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.435685, 0.310837]}
# --------------------
# Record(CHROM=MH893760.2, POS=11566, REF=TTTA, ALT=[T])
# 118
# [0, 0, 41, 72]
# {'INDEL': True, 'IDV': 111, 'IMF': 0.940678, 'DP': 118, 'VDB': 0.0807615, 'SGB': -0.693147, 'MQSB': 0.888318, 'MQ0F': 0.0254237, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 41, 72], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=11571, REF=TATA, ALT=[T])
# 120
# [1, 1, 40, 67]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00833333, 'DP': 120, 'VDB': 0.0137283, 'SGB': -0.693147, 'MQSB': 0.899702, 'MQ0F': 0.025, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 1, 40, 67], 'MQ': 41, 'FQ': -999.0, 'PV4': [1.0, 2.93656e-05, 0.365937, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=12055, REF=T, ALT=[TTG])
# 117
# [3, 2, 20, 38]
# {'INDEL': True, 'IDV': 4, 'IMF': 0.034188, 'DP': 117, 'VDB': 0.194602, 'SGB': -0.693147, 'MQSB': 0.999363, 'MQ0F': 0.0512821, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [3, 2, 20, 38], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.345325, 3.67989e-05, 0.306071, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=12057, REF=G, ALT=[GTT, GTTT])
# 116
# [0, 0, 51, 47]
# {'INDEL': True, 'IDV': 99, 'IMF': 0.853448, 'DP': 116, 'VDB': 0.20465, 'SGB': -0.693147, 'MQSB': 0.4651, 'MQ0F': 0.0517241, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 51, 47], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=16010, REF=T, ALT=[TA])
# 89
# [0, 1, 46, 34]
# {'INDEL': True, 'IDV': 77, 'IMF': 0.865169, 'DP': 89, 'VDB': 0.726075, 'SGB': -0.693147, 'MQSB': 0.998626, 'MQ0F': 0.011236, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 46, 34], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.432099, 1.0, 0.412569, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=18168, REF=CT, ALT=[C])
# 72
# [0, 0, 34, 32]
# {'INDEL': True, 'IDV': 68, 'IMF': 0.931507, 'DP': 72, 'VDB': 0.57387, 'SGB': -0.693147, 'MQSB': 0.995975, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 34, 32], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=27951, REF=A, ALT=[AT, ATT])
# 126
# [0, 0, 52, 58]
# {'INDEL': True, 'IDV': 108, 'IMF': 0.857143, 'DP': 126, 'VDB': 0.709823, 'SGB': -0.693147, 'MQSB': 0.85354, 'MQ0F': 0.031746, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 52, 58], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=40202, REF=AT, ALT=[A])
# 84
# [0, 0, 36, 39]
# {'INDEL': True, 'IDV': 77, 'IMF': 0.916667, 'DP': 84, 'VDB': 0.510574, 'SGB': -0.693147, 'MQSB': 0.940602, 'MQ0F': 0.0357143, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 36, 39], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=57346, REF=C, ALT=[CA, CAA])
# 88
# [0, 0, 43, 37]
# {'INDEL': True, 'IDV': 84, 'IMF': 0.954545, 'DP': 88, 'VDB': 0.858419, 'SGB': -0.693147, 'MQSB': 0.946092, 'MQ0F': 0.0227273, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 43, 37], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=57906, REF=AGCG, ALT=[A])
# 110
# [2, 1, 11, 40]
# {'INDEL': True, 'IDV': 5, 'IMF': 0.0454545, 'DP': 110, 'VDB': 0.927753, 'SGB': -0.693147, 'MQSB': 0.478632, 'MQ0F': 0.0909091, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [2, 1, 11, 40], 'MQ': 40, 'FQ': -999.0, 'PV4': [0.140461, 0.180946, 0.276489, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=57907, REF=GCGA, ALT=[G])
# 105
# [0, 0, 21, 48]
# {'INDEL': True, 'IDV': 90, 'IMF': 0.818182, 'DP': 105, 'VDB': 0.990754, 'SGB': -0.693147, 'MQSB': 0.205076, 'MQ0F': 0.0952381, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 21, 48], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=57914, REF=CGAT, ALT=[C])
# 110
# [0, 2, 15, 41]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00909091, 'DP': 110, 'VDB': 0.999802, 'SGB': -0.693147, 'MQSB': 0.341941, 'MQ0F': 0.0727273, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 2, 15, 41], 'MQ': 40, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.307592, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=57992, REF=A, ALT=[AT])
# 103
# [0, 0, 25, 49]
# {'INDEL': True, 'IDV': 85, 'IMF': 0.825243, 'DP': 103, 'VDB': 0.179295, 'SGB': -0.693147, 'MQSB': 0.970263, 'MQ0F': 0.0776699, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 25, 49], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=66862, REF=G, ALT=[A])
# 137
# [1, 0, 64, 69]
# {'DP': 137, 'VDB': 0.870541, 'SGB': -0.693147, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.961432, 'BQB': 1.0, 'MQ0F': 0.0145985, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 64, 69], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.485075, 1.0, 1.0, 0.494593]}
# --------------------
# Record(CHROM=MH893760.2, POS=73757, REF=A, ALT=[T])
# 82
# [0, 0, 41, 36]
# {'DP': 82, 'VDB': 0.358369, 'SGB': -0.693147, 'MQSB': 0.884627, 'MQ0F': 0.0121951, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 41, 36], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=84130, REF=A, ALT=[AT])
# 148
# [0, 0, 71, 73]
# {'INDEL': True, 'IDV': 146, 'IMF': 0.986486, 'DP': 148, 'VDB': 0.597936, 'SGB': -0.693147, 'MQSB': 0.999998, 'MQ0F': 0.0135135, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 71, 73], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=89921, REF=TGAA, ALT=[T])
# 149
# [0, 0, 56, 65]
# {'INDEL': True, 'IDV': 120, 'IMF': 0.794702, 'DP': 149, 'VDB': 0.134161, 'SGB': -0.693147, 'MQSB': 0.93594, 'MQ0F': 0.0134228, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 56, 65], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=99158, REF=A, ALT=[AT])
# 64
# [0, 0, 28, 35]
# {'INDEL': True, 'IDV': 63, 'IMF': 0.984375, 'DP': 64, 'VDB': 0.308308, 'SGB': -0.693147, 'MQSB': 0.768226, 'MQ0F': 0.03125, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 28, 35], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=117638, REF=A, ALT=[T])
# 116
# [0, 0, 57, 55]
# {'DP': 116, 'VDB': 0.923069, 'SGB': -0.693147, 'MQSB': 0.897272, 'MQ0F': 0.0258621, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 57, 55], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=122070, REF=T, ALT=[C])
# 57
# [2, 1, 27, 21]
# {'DP': 57, 'VDB': 0.261951, 'SGB': -0.693147, 'RPB': 0.0157039, 'MQB': 0.864129, 'MQSB': 1.0, 'BQB': 0.260031, 'MQ0F': 0.0350877, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [2, 1, 27, 21], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.248476, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=122071, REF=C, ALT=[T])
# 57
# [4, 3, 27, 21]
# {'DP': 57, 'VDB': 0.271245, 'SGB': -0.693147, 'RPB': 0.986618, 'MQB': 0.728763, 'MQSB': 0.999856, 'BQB': 0.874583, 'MQ0F': 0.0350877, 'AF1': 0.5, 'AC1': 1.0, 'DP4': [4, 3, 27, 21], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 0.312318, 0.149931, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=135383, REF=A, ALT=[AT])
# 51
# [0, 0, 21, 21]
# {'INDEL': True, 'IDV': 41, 'IMF': 0.803922, 'DP': 51, 'VDB': 0.230443, 'SGB': -0.693146, 'MQSB': 0.549515, 'MQ0F': 0.0784314, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 21, 21], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=135500, REF=A, ALT=[T])
# 54
# [0, 0, 37, 16]
# {'DP': 54, 'VDB': 0.265557, 'SGB': -0.693147, 'MQSB': 0.98806, 'MQ0F': 0.0555556, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 37, 16], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=137166, REF=G, ALT=[GT, GTT])
# 171
# [0, 0, 74, 84]
# {'INDEL': True, 'IDV': 161, 'IMF': 0.94152, 'DP': 171, 'VDB': 0.203465, 'SGB': -0.693147, 'MQSB': 0.99542, 'MQ0F': 0.0292398, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 74, 84], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=140549, REF=C, ALT=[CAAAAA])
# 163
# [0, 0, 73, 59]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00613497, 'DP': 163, 'VDB': 0.697335, 'SGB': -0.693147, 'MQSB': 0.562151, 'MQ0F': 0.0368098, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 73, 59], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=140558, REF=A, ALT=[AAAAAAT])
# 167
# [1, 6, 61, 54]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00598802, 'DP': 167, 'VDB': 0.661128, 'SGB': -0.693147, 'MQSB': 0.34212, 'MQ0F': 0.0359281, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 6, 61, 54], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.0594468, 1.0, 0.227097, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=145023, REF=GA, ALT=[G])
# 129
# [0, 0, 47, 73]
# {'INDEL': True, 'IDV': 113, 'IMF': 0.875969, 'DP': 129, 'VDB': 0.757602, 'SGB': -0.693147, 'MQSB': 0.986645, 'MQ0F': 0.00775194, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 47, 73], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145029, REF=AAT, ALT=[A])
# 126
# [2, 2, 3, 4]
# {'INDEL': True, 'IDV': 1, 'IMF': 0.00793651, 'DP': 126, 'VDB': 1.0, 'SGB': -0.636426, 'MQSB': 0.950952, 'MQ0F': 0.00793651, 'AF1': 0.5, 'AC1': 1.0, 'DP4': [2, 2, 3, 4], 'MQ': 42, 'FQ': -999.0, 'PV4': [1.0, 1.0, 1.0, 1.0]}
# --------------------
# Record(CHROM=MH893760.2, POS=145320, REF=C, ALT=[T])
# 136
# [0, 0, 70, 62]
# {'DP': 136, 'VDB': 0.494622, 'SGB': -0.693147, 'MQSB': 0.868421, 'MQ0F': 0.0294118, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 70, 62], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145323, REF=G, ALT=[T])
# 138
# [0, 0, 69, 63]
# {'DP': 138, 'VDB': 0.442293, 'SGB': -0.693147, 'MQSB': 0.920232, 'MQ0F': 0.0289855, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 69, 63], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145333, REF=G, ALT=[T])
# 140
# [0, 0, 72, 65]
# {'DP': 140, 'VDB': 0.565474, 'SGB': -0.693147, 'MQSB': 0.914641, 'MQ0F': 0.0285714, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 72, 65], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145339, REF=G, ALT=[T])
# 141
# [0, 0, 74, 66]
# {'DP': 141, 'VDB': 0.67048, 'SGB': -0.693147, 'MQSB': 0.834712, 'MQ0F': 0.0283688, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 74, 66], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=145762, REF=A, ALT=[AAAT])
# 92
# [0, 0, 43, 44]
# {'INDEL': True, 'IDV': 87, 'IMF': 0.945652, 'DP': 92, 'VDB': 0.253694, 'SGB': -0.693147, 'MQSB': 0.935539, 'MQ0F': 0.0326087, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 43, 44], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146672, REF=G, ALT=[A])
# 72
# [0, 0, 28, 40]
# {'DP': 72, 'VDB': 0.751391, 'SGB': -0.693147, 'MQSB': 0.727594, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 28, 40], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146675, REF=G, ALT=[T])
# 72
# [0, 0, 29, 39]
# {'DP': 72, 'VDB': 0.819747, 'SGB': -0.693147, 'MQSB': 0.821951, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 29, 39], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146678, REF=C, ALT=[A])
# 72
# [0, 0, 29, 38]
# {'DP': 72, 'VDB': 0.79177, 'SGB': -0.693147, 'MQSB': 0.856405, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 29, 38], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146705, REF=CN, ALT=[C])
# 61
# [0, 0, 23, 29]
# {'INDEL': True, 'IDV': 53, 'IMF': 0.868852, 'DP': 61, 'VDB': 0.496348, 'SGB': -0.693147, 'MQSB': 0.991718, 'MQ0F': 0.0327869, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 23, 29], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=146778, REF=T, ALT=[A])
# 65
# [0, 0, 34, 26]
# {'DP': 65, 'VDB': 0.631909, 'SGB': -0.693147, 'MQSB': 0.615893, 'MQ0F': 0.0461538, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 34, 26], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=148234, REF=A, ALT=[G])
# 70
# [0, 0, 36, 27]
# {'DP': 70, 'VDB': 0.146847, 'SGB': -0.693147, 'MQSB': 0.623374, 'MQ0F': 0.0571429, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 36, 27], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=148242, REF=A, ALT=[T])
# 72
# [0, 0, 36, 27]
# {'DP': 72, 'VDB': 0.151561, 'SGB': -0.693147, 'MQSB': 0.623374, 'MQ0F': 0.0694444, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 36, 27], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=MH893760.2, POS=148250, REF=G, ALT=[T])
# 72
# [0, 0, 38, 30]
# {'DP': 72, 'VDB': 0.276283, 'SGB': -0.693147, 'MQSB': 0.52434, 'MQ0F': 0.0694444, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 38, 30], 'MQ': 38, 'FQ': -999.0}
# --------------------
# 43
