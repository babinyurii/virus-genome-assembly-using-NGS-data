# %%
# %%bash
# mkdir ./samtools_out

# %% [markdown]
# ## these steps are needed to open bam file in IGV :
# - IGV takes sorted indexed `bam` file as an input

# %% [markdown]
# #### 1. convert a file from `sam` into `bam` format :

# %%
# %%bash
# samtools view \
# -b -S -o \
# ./samtools_out/saratov_map_unpaired.bam \
# ./bowtie_out/saratov_map_unpaired.sam

# %% [markdown]
# #### 2. sort reads by their genome positions :

# %%
# %%bash
# samtools sort ./samtools_out/saratov_map_unpaired.bam > ./samtools_out/saratov_map_unpaired_sorted.bam

# %% [markdown]
# #### 3. remove pcr duplicates from sorted file :

# %%
# %%bash
# samtools rmdup  ./samtools_out/saratov_map_unpaired_sorted.bam ./samtools_out/saratov_map_unpaired_sorted_rmdup.bam
# Out:
# [bam_rmdup_core] processing reference AF409138.1...

# %% [markdown]
# #### 4. indexing sorted file :

# %%
# %%bash
# samtools index ./samtools_out/saratov_map_unpaired_sorted_rmdup.bam

# %% [markdown]
# #### now you can open file `saratov_map_unpaired_sorted_rmdup.bam` with IGV to visualize mapping reads and variants :_

# %% [markdown]
# ![igv](./pictures/igv_example.png)

# %% [markdown]
# we can also import `sam` file into Ugene (it sorts, creates index and makes file `ugenedb`, which can be opened in Ugene afterwards) to visualize the mapped reads :

# %% [markdown]
# ![ugene](./pictures/ugene_example.png)

# %%
# %%bash
# ls ./input_data/
# Out:
# 1_trim_crop_and_trail_32_1P.fastq
# 1_trim_crop_and_trail_32_1U.fastq
# 1_trim_crop_and_trail_32_2P.fastq
# 1_trim_crop_and_trail_32_2U.fastq
# 2_trim_crop_and_trail_32_2P.fastq
# SUD-Saratov_S1_L001_R1_001.fastq
# SUD-Saratov_S1_L001_R2_001.fastq
# input_data.rar
# merged_document.aln
# ref_AF409138.1.fasta
# ref_AF409138.1.fasta.fai
# saratov_map_on_AF_consensus.fa

# %% [markdown]
# ####  6. calculating variants
# - `mpileup` calculates likelihoods of the variants
# - we can skip indels by `--skip-indels` flag (can be denoted as `-I` for short)
# - `--BCF` is the output option (output in binary call format) and may be `-g` for short
# - `--fasta` denots reference file format, can be `-f` for short

# %%
# %%bash
# samtools mpileup --BCF \
# --fasta ./input_data/ref_AF409138.1.fasta \
# ./samtools_out/saratov_map_unpaired_sorted_rmdup.bam > ./samtools_out/saratov_vars.bcf
# Out:
# [mpileup] 1 samples in 1 input files
# <mpileup> Set max per-file depth to 8000

# %% [markdown]
# #### 7. calling variants. conventional variant
# - `-c`, `--consensus-caller`  the original samtools/bcftools calling method (conflicts with -m)
# - `-v`, `--variants-only` output variant sites only
# - `-V`, `--skip-variants snps|indels` skip indel/SNP sites
# - `--ploidy-file` path to the file which denotes set of chromosomes, if not set, all samples are considered diploid. It's better to set it to improve variants call quality (use to get help : `bcftools call --ploidy ?`)

# %%
# %%bash
# bcftools call \
# --consensus-caller \
# --variants-only \
# --ploidy-file ./samtools_out/ploid.txt \
# ./samtools_out/saratov_vars.bcf > ./samtools_out/saratov_vars.vcf

# %% [markdown]
# #### from here we can parse `vcf` to explore the difference from the reference

# %%
import vcf

# %%
vcf_reader = vcf.Reader(open('./samtools_out/saratov_vars.vcf', 'r'))
counter = 0
for record in vcf_reader:
    print(record)
    print(record.INFO["DP"])
    print(record.INFO["DP4"])
    print(record.INFO)
    print("--------------------")
    counter += 1

print(counter)
# Out:
# Record(CHROM=AF409138.1, POS=502, REF=A, ALT=[G])
# 47
# [0, 0, 14, 26]
# {'DP': 47, 'VDB': 0.242997, 'SGB': -0.693145, 'MQSB': 0.20277, 'MQ0F': 0.340426, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 14, 26], 'MQ': 1, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=759, REF=C, ALT=[T])
# 24
# [0, 0, 7, 15]
# {'DP': 24, 'VDB': 0.001429, 'SGB': -0.692562, 'MQSB': 0.760398, 'MQ0F': 0.166667, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 15], 'MQ': 1, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5386, REF=A, ALT=[G])
# 10
# [0, 0, 1, 7]
# {'DP': 10, 'VDB': 0.020653, 'SGB': -0.651104, 'MQSB': 1.0, 'MQ0F': 0.1, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 7], 'MQ': 21, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5498, REF=T, ALT=[G])
# 21
# [0, 0, 13, 6]
# {'DP': 21, 'VDB': 0.650357, 'SGB': -0.69168, 'MQSB': 0.850016, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 13, 6], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5534, REF=A, ALT=[G])
# 16
# [0, 0, 4, 3]
# {'DP': 16, 'VDB': 0.0098501, 'SGB': -0.636426, 'MQSB': 0.810265, 'MQ0F': 0.0625, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 3], 'MQ': 20, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5536, REF=T, ALT=[C])
# 7
# [0, 0, 4, 2]
# {'DP': 7, 'VDB': 0.00688729, 'SGB': -0.616816, 'MQSB': 1.0, 'MQ0F': 0.142857, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 2], 'MQ': 19, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5562, REF=G, ALT=[A])
# 4
# [0, 0, 3, 0]
# {'DP': 4, 'VDB': 0.0221621, 'SGB': -0.511536, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 0], 'MQ': 19, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5574, REF=ATTTTTT, ALT=[ATTTTTTT])
# 7
# [0, 0, 5, 2]
# {'INDEL': True, 'IDV': 6, 'IMF': 0.857143, 'DP': 7, 'VDB': 0.0408989, 'SGB': -0.636426, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 2], 'MQ': 25, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5657, REF=G, ALT=[A, C])
# 14
# [0, 0, 1, 10]
# {'DP': 14, 'VDB': 0.84546, 'SGB': -0.676189, 'MQSB': 1.0, 'MQ0F': 0.214286, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 10], 'MQ': 31, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5735, REF=C, ALT=[T])
# 6
# [0, 0, 2, 4]
# {'DP': 6, 'VDB': 0.0769344, 'SGB': -0.616816, 'MQSB': 0.875, 'MQ0F': 0.333333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 4], 'MQ': 11, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5737, REF=C, ALT=[T])
# 6
# [0, 0, 2, 4]
# {'DP': 6, 'VDB': 0.0697235, 'SGB': -0.616816, 'MQSB': 0.875, 'MQ0F': 0.333333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 4], 'MQ': 11, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5762, REF=C, ALT=[T, G])
# 11
# [0, 0, 3, 8]
# {'DP': 11, 'VDB': 0.990565, 'SGB': -0.676189, 'MQSB': 0.994805, 'MQ0F': 0.181818, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 8], 'MQ': 25, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5775, REF=C, ALT=[T, G])
# 11
# [0, 0, 0, 10]
# {'DP': 11, 'VDB': 0.00835326, 'SGB': -0.670168, 'MQ0F': 0.181818, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 10], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5819, REF=T, ALT=[G])
# 7
# [0, 0, 4, 3]
# {'DP': 7, 'VDB': 0.00748664, 'SGB': -0.636426, 'MQSB': 0.202566, 'MQ0F': 0.142857, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 3], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=5886, REF=T, ALT=[C])
# 9
# [0, 0, 4, 4]
# {'DP': 9, 'VDB': 0.0330611, 'SGB': -0.651104, 'MQSB': 0.62023, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 4], 'MQ': 31, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=7772, REF=A, ALT=[G])
# 26
# [0, 0, 3, 17]
# {'DP': 26, 'VDB': 0.595873, 'SGB': -0.692067, 'MQSB': 0.95083, 'MQ0F': 0.0384615, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 17], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=7773, REF=T, ALT=[C, A])
# 28
# [0, 0, 3, 16]
# {'DP': 28, 'VDB': 0.408857, 'SGB': -0.69168, 'MQSB': 0.986036, 'MQ0F': 0.0357143, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 16], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=8466, REF=C, ALT=[A])
# 15
# [0, 0, 3, 11]
# {'DP': 15, 'VDB': 0.17229, 'SGB': -0.686358, 'MQSB': 0.334895, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 11], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=9540, REF=T, ALT=[C])
# 20
# [0, 0, 10, 5]
# {'DP': 20, 'VDB': 0.36186, 'SGB': -0.688148, 'MQSB': 0.728422, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 5], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=9597, REF=C, ALT=[T])
# 20
# [0, 0, 10, 7]
# {'DP': 20, 'VDB': 9.85389e-05, 'SGB': -0.690438, 'MQSB': 0.562035, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 7], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=9614, REF=C, ALT=[T])
# 14
# [0, 0, 3, 11]
# {'DP': 14, 'VDB': 0.0322662, 'SGB': -0.686358, 'MQSB': 0.374629, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 11], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=12429, REF=C, ALT=[A])
# 36
# [0, 0, 9, 21]
# {'DP': 36, 'VDB': 0.553623, 'SGB': -0.693097, 'MQSB': 0.609176, 'MQ0F': 0.0277778, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 21], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=12523, REF=G, ALT=[A])
# 24
# [0, 0, 20, 4]
# {'DP': 24, 'VDB': 0.00274279, 'SGB': -0.692831, 'MQSB': 0.953134, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 20, 4], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=12568, REF=C, ALT=[T])
# 15
# [0, 0, 9, 2]
# {'DP': 15, 'VDB': 0.0355294, 'SGB': -0.676189, 'MQSB': 0.555556, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 2], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=12583, REF=A, ALT=[G])
# 19
# [0, 0, 2, 12]
# {'DP': 19, 'VDB': 0.00517783, 'SGB': -0.686358, 'MQSB': 0.791667, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 12], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=12633, REF=C, ALT=[A])
# 22
# [0, 2, 8, 9]
# {'DP': 22, 'VDB': 0.269298, 'SGB': -0.690438, 'RPB': 1.0, 'MQB': 0.529412, 'MQSB': 1.0, 'BQB': 0.941176, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 2, 8, 9], 'MQ': 38, 'FQ': -999.0, 'PV4': [0.48538, 1.0, 0.253622, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=12723, REF=G, ALT=[A])
# 13
# [0, 0, 3, 8]
# {'DP': 13, 'VDB': 0.684373, 'SGB': -0.676189, 'MQSB': 0.954207, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 8], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=14451, REF=C, ALT=[T, G])
# 32
# [0, 0, 17, 14]
# {'DP': 32, 'VDB': 0.532986, 'SGB': -0.69311, 'MQSB': 0.916809, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 14], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=14499, REF=C, ALT=[T])
# 35
# [0, 0, 9, 25]
# {'DP': 35, 'VDB': 0.417885, 'SGB': -0.693132, 'MQSB': 0.99981, 'MQ0F': 0.0285714, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 25], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=14610, REF=G, ALT=[A, T, C])
# 55
# [0, 0, 3, 42]
# {'DP': 55, 'VDB': 0.0078431, 'SGB': -0.693147, 'MQSB': 0.935894, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 42], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=14721, REF=TA, ALT=[TAA])
# 13
# [0, 1, 1, 4]
# {'INDEL': True, 'IDV': 7, 'IMF': 0.538462, 'DP': 13, 'VDB': 0.893344, 'SGB': -0.590765, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 0.829413, 'AC1': 1.0, 'DP4': [0, 1, 1, 4], 'MQ': 31, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.211525, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=14764, REF=T, ALT=[G])
# 8
# [0, 0, 5, 2]
# {'DP': 8, 'VDB': 0.653727, 'SGB': -0.636426, 'MQSB': 0.8, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 2], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=14874, REF=A, ALT=[G])
# 17
# [0, 0, 9, 8]
# {'DP': 17, 'VDB': 0.404483, 'SGB': -0.690438, 'MQSB': 0.48511, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 8], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=15545, REF=CTTTTT, ALT=[CTTTTTT])
# 16
# [0, 0, 14, 1]
# {'INDEL': True, 'IDV': 12, 'IMF': 0.75, 'DP': 16, 'VDB': 0.107561, 'SGB': -0.688148, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 14, 1], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=15605, REF=A, ALT=[G])
# 34
# [0, 0, 18, 14]
# {'DP': 34, 'VDB': 0.0946132, 'SGB': -0.69312, 'MQSB': 0.0959281, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 18, 14], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=16415, REF=C, ALT=[T])
# 13
# [0, 0, 3, 9]
# {'DP': 13, 'VDB': 0.0523689, 'SGB': -0.680642, 'MQSB': 0.432745, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 9], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=16469, REF=T, ALT=[C, G])
# 26
# [0, 0, 12, 12]
# {'DP': 26, 'VDB': 0.991832, 'SGB': -0.692831, 'MQSB': 0.617753, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 12, 12], 'MQ': 33, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=16498, REF=A, ALT=[G, T])
# 27
# [0, 0, 9, 16]
# {'DP': 27, 'VDB': 0.100705, 'SGB': -0.692914, 'MQSB': 0.594978, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 16], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=18386, REF=T, ALT=[G, C])
# 11
# [0, 0, 4, 7]
# {'DP': 11, 'VDB': 0.406086, 'SGB': -0.676189, 'MQSB': 0.0401934, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 7], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=19764, REF=T, ALT=[C])
# 19
# [0, 0, 5, 10]
# {'DP': 19, 'VDB': 0.873702, 'SGB': -0.688148, 'MQSB': 0.544711, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 10], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20014, REF=C, ALT=[T, G])
# 8
# [0, 0, 1, 5]
# {'DP': 8, 'VDB': 0.0846985, 'SGB': -0.616816, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 5], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20156, REF=C, ALT=[T])
# 12
# [0, 0, 9, 1]
# {'DP': 12, 'VDB': 0.00186926, 'SGB': -0.670168, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 1], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20167, REF=A, ALT=[G])
# 5
# [0, 0, 2, 0]
# {'DP': 5, 'VDB': 0.14, 'SGB': -0.453602, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 0], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20188, REF=C, ALT=[T])
# 3
# [0, 0, 0, 3]
# {'DP': 3, 'VDB': 0.21346, 'SGB': -0.511536, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 3], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20251, REF=G, ALT=[A])
# 9
# [0, 0, 2, 4]
# {'DP': 9, 'VDB': 0.936955, 'SGB': -0.616816, 'MQSB': 0.75, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 4], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20350, REF=G, ALT=[A])
# 23
# [0, 0, 15, 5]
# {'DP': 23, 'VDB': 0.51179, 'SGB': -0.692067, 'MQSB': 0.991465, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 5], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=20617, REF=C, ALT=[T])
# 21
# [0, 0, 6, 14]
# {'DP': 21, 'VDB': 0.306029, 'SGB': -0.692067, 'MQSB': 0.513417, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 14], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=21462, REF=T, ALT=[C, G])
# 28
# [0, 0, 15, 10]
# {'DP': 28, 'VDB': 0.595584, 'SGB': -0.692914, 'MQSB': 0.121705, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 10], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=21466, REF=A, ALT=[G])
# 28
# [0, 0, 10, 10]
# {'DP': 28, 'VDB': 0.9559, 'SGB': -0.692067, 'MQSB': 0.115243, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 10], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=22605, REF=A, ALT=[G])
# 26
# [0, 0, 8, 17]
# {'DP': 26, 'VDB': 0.110825, 'SGB': -0.692914, 'MQSB': 0.998305, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 17], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=23103, REF=C, ALT=[T, A])
# 13
# [0, 0, 9, 3]
# {'DP': 13, 'VDB': 0.287329, 'SGB': -0.680642, 'MQSB': 0.485672, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 3], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=23138, REF=T, ALT=[G])
# 18
# [0, 1, 5, 10]
# {'DP': 18, 'VDB': 0.452471, 'SGB': -0.688148, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.960687, 'BQB': 1.0, 'MQ0F': 0.0555556, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 5, 10], 'MQ': 35, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.236657, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=26021, REF=G, ALT=[A, C])
# 13
# [0, 0, 2, 10]
# {'DP': 13, 'VDB': 0.394296, 'SGB': -0.680642, 'MQSB': 0.7, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 10], 'MQ': 42, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=26070, REF=C, ALT=[T])
# 37
# [0, 2, 17, 16]
# {'DP': 37, 'VDB': 0.000444035, 'SGB': -0.693127, 'RPB': 0.681818, 'MQB': 0.575758, 'MQSB': 0.854356, 'BQB': 0.212121, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 2, 17, 16], 'MQ': 40, 'FQ': -999.0, 'PV4': [0.485714, 1.0, 0.274129, 0.329459]}
# --------------------
# Record(CHROM=AF409138.1, POS=26173, REF=C, ALT=[G])
# 2
# [0, 0, 1, 1]
# {'DP': 2, 'VDB': 0.6, 'SGB': -0.453602, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 1], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=26232, REF=A, ALT=[G])
# 8
# [0, 0, 1, 7]
# {'DP': 8, 'VDB': 0.237012, 'SGB': -0.651104, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 7], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=27805, REF=ATTTTT, ALT=[ATTTTTT])
# 12
# [0, 0, 5, 0]
# {'INDEL': True, 'IDV': 7, 'IMF': 0.583333, 'DP': 12, 'VDB': 0.210092, 'SGB': -0.590765, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 0], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=27885, REF=T, ALT=[C])
# 34
# [0, 0, 18, 16]
# {'DP': 34, 'VDB': 0.0305142, 'SGB': -0.693132, 'MQSB': 0.00648609, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 18, 16], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=27990, REF=G, ALT=[A, C])
# 16
# [0, 0, 7, 6]
# {'DP': 16, 'VDB': 0.595846, 'SGB': -0.683931, 'MQSB': 0.623736, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 6], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=28047, REF=G, ALT=[A, T])
# 21
# [0, 0, 6, 13]
# {'DP': 21, 'VDB': 0.0585785, 'SGB': -0.69168, 'MQSB': 0.350949, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 13], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=28175, REF=A, ALT=[G])
# 24
# [0, 0, 11, 8]
# {'DP': 24, 'VDB': 0.016364, 'SGB': -0.69168, 'MQSB': 0.946915, 'MQ0F': 0.0833333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 11, 8], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=28224, REF=A, ALT=[G])
# 25
# [0, 0, 10, 14]
# {'DP': 25, 'VDB': 0.220289, 'SGB': -0.692831, 'MQSB': 0.573826, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 14], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=28257, REF=A, ALT=[G, T])
# 34
# [0, 0, 4, 28]
# {'DP': 34, 'VDB': 6.81048e-05, 'SGB': -0.69312, 'MQSB': 0.306223, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 28], 'MQ': 31, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=29443, REF=T, ALT=[C])
# 20
# [0, 0, 2, 16]
# {'DP': 20, 'VDB': 0.00267966, 'SGB': -0.691153, 'MQSB': 0.4375, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 16], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=29681, REF=AT, ALT=[A])
# 24
# [0, 0, 9, 6]
# {'INDEL': True, 'IDV': 18, 'IMF': 0.75, 'DP': 24, 'VDB': 0.0742274, 'SGB': -0.688148, 'MQSB': 0.840624, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 6], 'MQ': 33, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=29908, REF=G, ALT=[A])
# 44
# [0, 0, 16, 26]
# {'DP': 44, 'VDB': 3.07683e-10, 'SGB': -0.693146, 'MQSB': 0.931907, 'MQ0F': 0.0227273, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 16, 26], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=30289, REF=C, ALT=[T, A])
# 10
# [0, 0, 4, 4]
# {'DP': 10, 'VDB': 0.585032, 'SGB': -0.651104, 'MQSB': 0.992367, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 4], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=30434, REF=T, ALT=[G])
# 21
# [0, 1, 7, 12]
# {'DP': 21, 'VDB': 0.00921026, 'SGB': -0.69168, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.992961, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 7, 12], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.398609, 0.46388]}
# --------------------
# Record(CHROM=AF409138.1, POS=30523, REF=C, ALT=[T])
# 17
# [0, 0, 7, 10]
# {'DP': 17, 'VDB': 0.00232799, 'SGB': -0.690438, 'MQSB': 0.92664, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 10], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=30581, REF=A, ALT=[G])
# 12
# [0, 0, 10, 2]
# {'DP': 12, 'VDB': 0.00127688, 'SGB': -0.680642, 'MQSB': 0.8, 'MQ0F': 0.0833333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 2], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=30961, REF=A, ALT=[G])
# 17
# [0, 0, 6, 8]
# {'DP': 17, 'VDB': 0.0171822, 'SGB': -0.686358, 'MQSB': 0.509156, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 8], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=30994, REF=G, ALT=[A])
# 13
# [0, 0, 12, 1]
# {'DP': 13, 'VDB': 0.610232, 'SGB': -0.683931, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 12, 1], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=31141, REF=A, ALT=[G])
# 25
# [0, 0, 15, 9]
# {'DP': 25, 'VDB': 0.566267, 'SGB': -0.692831, 'MQSB': 0.978458, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 9], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=31633, REF=C, ALT=[A])
# 12
# [0, 0, 2, 3]
# {'DP': 12, 'VDB': 0.422633, 'SGB': -0.590765, 'MQSB': 0.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 3], 'MQ': 31, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=31954, REF=G, ALT=[A])
# 35
# [0, 0, 10, 7]
# {'DP': 35, 'VDB': 0.428746, 'SGB': -0.690438, 'MQSB': 0.99881, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 7], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32002, REF=C, ALT=[T, G, A])
# 18
# [0, 0, 6, 10]
# {'DP': 18, 'VDB': 0.0336189, 'SGB': -0.689466, 'MQSB': 0.490777, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 10], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32044, REF=A, ALT=[T])
# 14
# [1, 0, 6, 6]
# {'DP': 14, 'VDB': 0.391706, 'SGB': -0.680642, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.920266, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 6, 6], 'MQ': 38, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.25131, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=32266, REF=C, ALT=[T])
# 6
# [0, 0, 3, 2]
# {'DP': 6, 'VDB': 0.0550147, 'SGB': -0.590765, 'MQSB': 0.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 2], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32281, REF=A, ALT=[G])
# 4
# [0, 0, 0, 3]
# {'DP': 4, 'VDB': 0.0681597, 'SGB': -0.511536, 'MQ0F': 0.25, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 3], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32284, REF=C, ALT=[T])
# 4
# [0, 0, 0, 3]
# {'DP': 4, 'VDB': 0.0681597, 'SGB': -0.511536, 'MQ0F': 0.25, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 3], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32497, REF=A, ALT=[G])
# 33
# [0, 0, 16, 16]
# {'DP': 33, 'VDB': 0.00348412, 'SGB': -0.69312, 'MQSB': 0.215307, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 16, 16], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32701, REF=T, ALT=[C])
# 16
# [0, 0, 13, 1]
# {'DP': 16, 'VDB': 0.0117032, 'SGB': -0.686358, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 13, 1], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32713, REF=C, ALT=[T])
# 13
# [0, 0, 7, 5]
# {'DP': 13, 'VDB': 0.985402, 'SGB': -0.680642, 'MQSB': 0.838008, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 5], 'MQ': 33, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=32743, REF=G, ALT=[A])
# 36
# [0, 0, 14, 20]
# {'DP': 36, 'VDB': 0.04022, 'SGB': -0.693132, 'MQSB': 0.966147, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 14, 20], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=37272, REF=A, ALT=[G])
# 25
# [0, 0, 3, 22]
# {'DP': 25, 'VDB': 1.67778e-06, 'SGB': -0.692914, 'MQSB': 0.604414, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 22], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=37294, REF=G, ALT=[A, C])
# 6
# [0, 0, 2, 3]
# {'DP': 6, 'VDB': 0.233642, 'SGB': -0.590765, 'MQSB': 0.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 3], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=37402, REF=T, ALT=[C, G])
# 11
# [0, 0, 4, 3]
# {'DP': 11, 'VDB': 0.405339, 'SGB': -0.636426, 'MQSB': 0.405132, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 3], 'MQ': 29, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=37404, REF=C, ALT=[T, G, A])
# 10
# [0, 0, 4, 3]
# {'DP': 10, 'VDB': 0.436369, 'SGB': -0.636426, 'MQSB': 0.405132, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 3], 'MQ': 29, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=37564, REF=A, ALT=[G])
# 30
# [0, 0, 9, 14]
# {'DP': 30, 'VDB': 0.115894, 'SGB': -0.692717, 'MQSB': 0.289361, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 14], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=37693, REF=A, ALT=[G, C])
# 28
# [0, 0, 14, 12]
# {'DP': 28, 'VDB': 0.675262, 'SGB': -0.692976, 'MQSB': 0.216731, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 14, 12], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43220, REF=C, ALT=[T])
# 30
# [0, 0, 21, 7]
# {'DP': 30, 'VDB': 0.742067, 'SGB': -0.693054, 'MQSB': 0.91386, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 21, 7], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43293, REF=A, ALT=[G])
# 27
# [0, 0, 17, 9]
# {'DP': 27, 'VDB': 0.773287, 'SGB': -0.692976, 'MQSB': 0.418189, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 9], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43328, REF=G, ALT=[A])
# 38
# [0, 0, 28, 7]
# {'DP': 38, 'VDB': 0.321014, 'SGB': -0.693136, 'MQSB': 0.57526, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 28, 7], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43439, REF=C, ALT=[T])
# 18
# [0, 0, 5, 13]
# {'DP': 18, 'VDB': 0.0069682, 'SGB': -0.691153, 'MQSB': 0.863325, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 13], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43742, REF=T, ALT=[C])
# 34
# [0, 0, 7, 23]
# {'DP': 34, 'VDB': 0.228077, 'SGB': -0.693097, 'MQSB': 0.0438567, 'MQ0F': 0.0294118, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 23], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43850, REF=T, ALT=[G])
# 29
# [0, 0, 20, 6]
# {'DP': 29, 'VDB': 0.172245, 'SGB': -0.692976, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 20, 6], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=43895, REF=C, ALT=[T])
# 45
# [0, 0, 13, 31]
# {'DP': 45, 'VDB': 0.00132604, 'SGB': -0.693146, 'MQSB': 0.937211, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 13, 31], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=44501, REF=A, ALT=[G])
# 23
# [0, 0, 10, 12]
# {'DP': 23, 'VDB': 0.00570971, 'SGB': -0.692562, 'MQSB': 0.854648, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 12], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=44699, REF=C, ALT=[A])
# 15
# [0, 0, 6, 8]
# {'DP': 15, 'VDB': 0.241919, 'SGB': -0.686358, 'MQSB': 0.740818, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 8], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=44728, REF=G, ALT=[A, C])
# 25
# [0, 0, 2, 20]
# {'DP': 25, 'VDB': 0.0113889, 'SGB': -0.692562, 'MQSB': 0.2, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 20], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=44877, REF=A, ALT=[G])
# 14
# [0, 0, 13, 1]
# {'DP': 14, 'VDB': 0.139788, 'SGB': -0.686358, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 13, 1], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=45569, REF=A, ALT=[G, T, C])
# 19
# [0, 0, 8, 11]
# {'DP': 19, 'VDB': 0.000725691, 'SGB': -0.69168, 'MQSB': 0.587035, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 11], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=45884, REF=A, ALT=[G])
# 26
# [0, 0, 15, 10]
# {'DP': 26, 'VDB': 0.308196, 'SGB': -0.692914, 'MQSB': 0.882836, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 10], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=46508, REF=A, ALT=[G, C])
# 52
# [0, 0, 9, 39]
# {'DP': 52, 'VDB': 0.0417261, 'SGB': -0.693147, 'MQSB': 0.914564, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 39], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=46634, REF=C, ALT=[T])
# 37
# [0, 0, 17, 18]
# {'DP': 37, 'VDB': 0.0775508, 'SGB': -0.693136, 'MQSB': 0.0932427, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 18], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=46717, REF=A, ALT=[G, C])
# 17
# [0, 0, 12, 5]
# {'DP': 17, 'VDB': 0.906776, 'SGB': -0.690438, 'MQSB': 0.761685, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 12, 5], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=46819, REF=C, ALT=[T])
# 25
# [0, 0, 15, 10]
# {'DP': 25, 'VDB': 0.220231, 'SGB': -0.692914, 'MQSB': 0.927387, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 10], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=46852, REF=T, ALT=[C])
# 12
# [0, 0, 4, 8]
# {'DP': 12, 'VDB': 0.848205, 'SGB': -0.680642, 'MQSB': 0.0249144, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 8], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=46906, REF=A, ALT=[T, G])
# 20
# [2, 0, 8, 8]
# {'DP': 20, 'VDB': 0.891894, 'SGB': -0.689466, 'RPB': 0.75, 'MQB': 0.8125, 'MQSB': 0.906029, 'BQB': 0.3125, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [2, 0, 8, 8], 'MQ': 41, 'FQ': -999.0, 'PV4': [0.477124, 1.0, 0.339263, 0.117894]}
# --------------------
# Record(CHROM=AF409138.1, POS=47180, REF=G, ALT=[A])
# 12
# [0, 0, 6, 4]
# {'DP': 12, 'VDB': 0.117011, 'SGB': -0.670168, 'MQSB': 0.167959, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 4], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=47777, REF=A, ALT=[G])
# 32
# [0, 0, 19, 8]
# {'DP': 32, 'VDB': 0.00125761, 'SGB': -0.693021, 'MQSB': 0.843173, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 19, 8], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=47813, REF=C, ALT=[T])
# 24
# [0, 0, 8, 16]
# {'DP': 24, 'VDB': 0.0473017, 'SGB': -0.692831, 'MQSB': 0.0338195, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 16], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48165, REF=A, ALT=[G])
# 6
# [0, 0, 2, 4]
# {'DP': 6, 'VDB': 0.9708, 'SGB': -0.616816, 'MQSB': 0.25, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 4], 'MQ': 29, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48172, REF=G, ALT=[A])
# 10
# [0, 0, 2, 3]
# {'DP': 10, 'VDB': 0.0236989, 'SGB': -0.590765, 'MQSB': 0.5, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 3], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48513, REF=C, ALT=[T, A, G])
# 45
# [0, 0, 31, 10]
# {'DP': 45, 'VDB': 0.0218846, 'SGB': -0.693145, 'MQSB': 0.0270699, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 31, 10], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48516, REF=T, ALT=[C, G])
# 46
# [0, 0, 31, 10]
# {'DP': 46, 'VDB': 0.0225974, 'SGB': -0.693145, 'MQSB': 0.0270699, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 31, 10], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48564, REF=A, ALT=[G])
# 37
# [0, 0, 15, 19]
# {'DP': 37, 'VDB': 0.402193, 'SGB': -0.693132, 'MQSB': 0.994601, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 19], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48618, REF=A, ALT=[G])
# 55
# [0, 0, 27, 28]
# {'DP': 55, 'VDB': 0.000176701, 'SGB': -0.693147, 'MQSB': 0.200396, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 27, 28], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=48744, REF=G, ALT=[T])
# 29
# [4, 0, 1, 24]
# {'DP': 29, 'VDB': 0.871526, 'SGB': -0.692914, 'RPB': 0.951229, 'MQB': 0.580132, 'MQSB': 0.398353, 'BQB': 0.0441351, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [4, 0, 1, 24], 'MQ': 38, 'FQ': -999.0, 'PV4': [0.000210517, 1.0, 0.133043, 0.0471668]}
# --------------------
# Record(CHROM=AF409138.1, POS=49832, REF=G, ALT=[T])
# 25
# [3, 0, 14, 8]
# {'DP': 25, 'VDB': 0.0181563, 'SGB': -0.692562, 'RPB': 0.704935, 'MQB': 0.916299, 'MQSB': 0.0708293, 'BQB': 0.0429872, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [3, 0, 14, 8], 'MQ': 38, 'FQ': -999.0, 'PV4': [0.526956, 1.0, 1.0, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=49846, REF=C, ALT=[T])
# 17
# [0, 0, 6, 7]
# {'DP': 17, 'VDB': 0.865136, 'SGB': -0.683931, 'MQSB': 0.695312, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 7], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=49892, REF=T, ALT=[C])
# 17
# [0, 0, 10, 6]
# {'DP': 17, 'VDB': 0.247698, 'SGB': -0.689466, 'MQSB': 0.290322, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 6], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50029, REF=G, ALT=[A])
# 12
# [0, 0, 4, 5]
# {'DP': 12, 'VDB': 0.946069, 'SGB': -0.662043, 'MQSB': 0.406082, 'MQ0F': 0.0833333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 5], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50037, REF=G, ALT=[A])
# 6
# [0, 0, 3, 2]
# {'DP': 6, 'VDB': 0.170249, 'SGB': -0.590765, 'MQSB': 0.166667, 'MQ0F': 0.166667, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 2], 'MQ': 18, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50064, REF=T, ALT=[C, A])
# 13
# [0, 0, 5, 6]
# {'DP': 13, 'VDB': 0.768075, 'SGB': -0.676189, 'MQSB': 0.950952, 'MQ0F': 0.0769231, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 6], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50233, REF=T, ALT=[C, G])
# 43
# [0, 0, 31, 6]
# {'DP': 43, 'VDB': 0.00483067, 'SGB': -0.693141, 'MQSB': 0.0634144, 'MQ0F': 0.0465116, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 31, 6], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50269, REF=T, ALT=[C])
# 28
# [0, 0, 20, 5]
# {'DP': 28, 'VDB': 0.0215562, 'SGB': -0.692914, 'MQSB': 0.829508, 'MQ0F': 0.142857, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 20, 5], 'MQ': 22, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50272, REF=A, ALT=[G])
# 27
# [0, 0, 18, 3]
# {'DP': 27, 'VDB': 0.0244341, 'SGB': -0.692352, 'MQSB': 0.807846, 'MQ0F': 0.148148, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 18, 3], 'MQ': 21, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=50408, REF=G, ALT=[A, C])
# 27
# [0, 0, 9, 17]
# {'DP': 27, 'VDB': 0.00374181, 'SGB': -0.692976, 'MQSB': 0.864812, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 17], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=52778, REF=C, ALT=[T])
# 7
# [0, 0, 4, 3]
# {'DP': 7, 'VDB': 0.00467508, 'SGB': -0.636426, 'MQSB': 0.810265, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 3], 'MQ': 25, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=52789, REF=C, ALT=[T])
# 8
# [0, 0, 5, 1]
# {'DP': 8, 'VDB': 0.565215, 'SGB': -0.616816, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 1], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=53788, REF=T, ALT=[A])
# 14
# [0, 2, 2, 6]
# {'DP': 14, 'VDB': 0.316575, 'SGB': -0.651104, 'RPB': 0.6875, 'MQB': 0.375, 'MQSB': 0.0, 'BQB': 0.3125, 'MQ0F': 0.0, 'AF1': 0.571816, 'AC1': 1.0, 'DP4': [0, 2, 2, 6], 'MQ': 26, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.115895, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=53792, REF=T, ALT=[C])
# 12
# [0, 0, 2, 10]
# {'DP': 12, 'VDB': 0.355991, 'SGB': -0.680642, 'MQSB': 0.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 10], 'MQ': 29, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=53840, REF=G, ALT=[C])
# 19
# [1, 0, 7, 7]
# {'DP': 19, 'VDB': 0.262455, 'SGB': -0.686358, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.68614, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 7, 7], 'MQ': 36, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.260603, 0.0816548]}
# --------------------
# Record(CHROM=AF409138.1, POS=53954, REF=C, ALT=[A, T])
# 14
# [0, 1, 7, 4]
# {'DP': 14, 'VDB': 0.128058, 'SGB': -0.676189, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.40926, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 7, 4], 'MQ': 38, 'FQ': -999.0, 'PV4': [0.416667, 1.0, 0.276607, 0.456182]}
# --------------------
# Record(CHROM=AF409138.1, POS=54051, REF=G, ALT=[A])
# 10
# [0, 0, 6, 3]
# {'DP': 10, 'VDB': 0.00123678, 'SGB': -0.662043, 'MQSB': 0.462292, 'MQ0F': 0.4, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 3], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54105, REF=T, ALT=[G])
# 13
# [0, 0, 12, 0]
# {'DP': 13, 'VDB': 0.0468491, 'SGB': -0.680642, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 12, 0], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54230, REF=C, ALT=[T])
# 45
# [0, 0, 8, 35]
# {'DP': 45, 'VDB': 0.250593, 'SGB': -0.693146, 'MQSB': 0.987898, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 35], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54300, REF=A, ALT=[G])
# 47
# [0, 0, 22, 19]
# {'DP': 47, 'VDB': 0.191273, 'SGB': -0.693145, 'MQSB': 0.905951, 'MQ0F': 0.0212766, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 22, 19], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54369, REF=T, ALT=[C])
# 13
# [0, 0, 8, 4]
# {'DP': 13, 'VDB': 0.223642, 'SGB': -0.680642, 'MQSB': 0.397295, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 4], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54493, REF=T, ALT=[C])
# 16
# [0, 0, 8, 8]
# {'DP': 16, 'VDB': 1.42188e-05, 'SGB': -0.689466, 'MQSB': 0.136585, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 8], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54507, REF=A, ALT=[G])
# 5
# [0, 0, 2, 2]
# {'DP': 5, 'VDB': 0.775568, 'SGB': -0.556411, 'MQSB': 0.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 2], 'MQ': 18, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54534, REF=A, ALT=[G, C])
# 24
# [0, 0, 20, 2]
# {'DP': 24, 'VDB': 0.990321, 'SGB': -0.692562, 'MQSB': 0.775, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 20, 2], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=54858, REF=T, ALT=[C])
# 36
# [0, 0, 10, 24]
# {'DP': 36, 'VDB': 0.00085763, 'SGB': -0.693132, 'MQSB': 0.982301, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 24], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=55190, REF=C, ALT=[G])
# 22
# [0, 1, 6, 13]
# {'DP': 22, 'VDB': 0.989613, 'SGB': -0.69168, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.687289, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 6, 13], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.286335, 0.222837]}
# --------------------
# Record(CHROM=AF409138.1, POS=55382, REF=A, ALT=[G])
# 38
# [0, 0, 17, 16]
# {'DP': 38, 'VDB': 0.0873195, 'SGB': -0.693127, 'MQSB': 0.0793147, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 16], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=55496, REF=T, ALT=[C])
# 15
# [0, 0, 11, 2]
# {'DP': 15, 'VDB': 0.0273298, 'SGB': -0.683931, 'MQSB': 0.909091, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 11, 2], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=56635, REF=GAAAA, ALT=[GAAAAA])
# 14
# [0, 0, 2, 1]
# {'INDEL': True, 'IDV': 6, 'IMF': 0.428571, 'DP': 14, 'VDB': 0.045681, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.285714, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 1], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=56653, REF=ATTTTTT, ALT=[ATTTTTTTT, ATTTTTTT])
# 13
# [0, 0, 3, 4]
# {'INDEL': True, 'IDV': 12, 'IMF': 0.923077, 'DP': 13, 'VDB': 0.0827521, 'SGB': -0.636426, 'MQSB': 0.810265, 'MQ0F': 0.384615, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 4], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=56823, REF=A, ALT=[G, C])
# 24
# [0, 0, 10, 14]
# {'DP': 24, 'VDB': 0.784293, 'SGB': -0.692831, 'MQSB': 0.979219, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 14], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=59987, REF=C, ALT=[T, G])
# 27
# [0, 0, 26, 0]
# {'DP': 27, 'VDB': 3.94339e-05, 'SGB': -0.692976, 'MQ0F': 0.0740741, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 26, 0], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=59993, REF=A, ALT=[G])
# 22
# [0, 0, 19, 0]
# {'DP': 22, 'VDB': 2.87987e-06, 'SGB': -0.69168, 'MQ0F': 0.0909091, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 19, 0], 'MQ': 21, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=60005, REF=T, ALT=[C])
# 9
# [0, 0, 6, 0]
# {'DP': 9, 'VDB': 0.000757574, 'SGB': -0.616816, 'MQ0F': 0.222222, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 0], 'MQ': 19, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=60023, REF=C, ALT=[T])
# 10
# [0, 0, 4, 5]
# {'DP': 10, 'VDB': 0.00270021, 'SGB': -0.662043, 'MQSB': 0.89338, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 5], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=61952, REF=C, ALT=[T, G])
# 33
# [0, 0, 22, 6]
# {'DP': 33, 'VDB': 0.00516941, 'SGB': -0.693054, 'MQSB': 0.452261, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 22, 6], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=61955, REF=A, ALT=[G])
# 31
# [0, 0, 21, 6]
# {'DP': 31, 'VDB': 0.00499167, 'SGB': -0.693021, 'MQSB': 0.439056, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 21, 6], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=62186, REF=G, ALT=[T])
# 34
# [3, 0, 9, 12]
# {'DP': 34, 'VDB': 0.488549, 'SGB': -0.692352, 'RPB': 0.891154, 'MQB': 0.101605, 'MQSB': 0.0272215, 'BQB': 0.851333, 'MQ0F': 0.0588235, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [3, 0, 9, 12], 'MQ': 32, 'FQ': -999.0, 'PV4': [0.217391, 1.0, 0.0322694, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=62189, REF=T, ALT=[C])
# 32
# [0, 0, 8, 12]
# {'DP': 32, 'VDB': 0.923811, 'SGB': -0.692067, 'MQSB': 0.114218, 'MQ0F': 0.0625, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 12], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=62363, REF=A, ALT=[G])
# 16
# [0, 0, 4, 8]
# {'DP': 16, 'VDB': 0.100499, 'SGB': -0.680642, 'MQSB': 0.793923, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 8], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=62524, REF=G, ALT=[A])
# 19
# [0, 0, 5, 10]
# {'DP': 19, 'VDB': 0.593461, 'SGB': -0.688148, 'MQSB': 0.76338, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 10], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=63057, REF=C, ALT=[T, A])
# 14
# [0, 0, 9, 0]
# {'DP': 14, 'VDB': 0.159195, 'SGB': -0.662043, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 0], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=63065, REF=A, ALT=[G])
# 7
# [0, 0, 7, 0]
# {'DP': 7, 'VDB': 0.834632, 'SGB': -0.636426, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 0], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=63278, REF=A, ALT=[G])
# 46
# [0, 0, 17, 27]
# {'DP': 46, 'VDB': 0.123466, 'SGB': -0.693146, 'MQSB': 0.562572, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 27], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=63374, REF=T, ALT=[C, G])
# 32
# [0, 0, 26, 3]
# {'DP': 32, 'VDB': 0.0643056, 'SGB': -0.693079, 'MQSB': 0.133954, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 26, 3], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=63527, REF=C, ALT=[A])
# 49
# [0, 0, 11, 36]
# {'DP': 49, 'VDB': 0.492876, 'SGB': -0.693147, 'MQSB': 0.864234, 'MQ0F': 0.0204082, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 11, 36], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=63725, REF=T, ALT=[C])
# 40
# [0, 0, 6, 33]
# {'DP': 40, 'VDB': 0.00349934, 'SGB': -0.693144, 'MQSB': 0.162198, 'MQ0F': 0.025, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 33], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=64063, REF=C, ALT=[T, G])
# 15
# [0, 0, 5, 6]
# {'DP': 15, 'VDB': 0.22041, 'SGB': -0.676189, 'MQSB': 0.950952, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 6], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=64222, REF=C, ALT=[T, G])
# 25
# [0, 1, 13, 7]
# {'DP': 25, 'VDB': 0.944417, 'SGB': -0.692067, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.663818, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 13, 7], 'MQ': 38, 'FQ': -999.0, 'PV4': [0.380952, 1.0, 0.293745, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=64357, REF=T, ALT=[A])
# 33
# [0, 5, 13, 8]
# {'DP': 33, 'VDB': 0.0445311, 'SGB': -0.692352, 'RPB': 0.122456, 'MQB': 0.266401, 'MQSB': 0.827498, 'BQB': 0.660463, 'MQ0F': 0.0909091, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 5, 13, 8], 'MQ': 30, 'FQ': -999.0, 'PV4': [0.0391304, 1.0, 0.0795636, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=64368, REF=A, ALT=[C])
# 32
# [1, 0, 5, 24]
# {'DP': 32, 'VDB': 0.0358277, 'SGB': -0.693079, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.16685, 'BQB': 1.0, 'MQ0F': 0.125, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 5, 24], 'MQ': 26, 'FQ': -999.0, 'PV4': [0.2, 1.0, 1.0, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=65003, REF=T, ALT=[C])
# 60
# [0, 0, 44, 9]
# {'DP': 60, 'VDB': 0.0551472, 'SGB': -0.693147, 'MQSB': 0.588055, 'MQ0F': 0.0166667, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 44, 9], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=65439, REF=C, ALT=[T])
# 10
# [0, 0, 6, 3]
# {'DP': 10, 'VDB': 0.0379436, 'SGB': -0.662043, 'MQSB': 0.115573, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 3], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=66022, REF=A, ALT=[G])
# 34
# [1, 0, 19, 12]
# {'DP': 34, 'VDB': 0.955958, 'SGB': -0.69311, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.80337, 'BQB': 1.0, 'MQ0F': 0.0588235, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 19, 12], 'MQ': 24, 'FQ': -999.0, 'PV4': [1.0, 1.0, 1.0, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=66028, REF=T, ALT=[G])
# 31
# [0, 0, 7, 16]
# {'DP': 31, 'VDB': 0.00521689, 'SGB': -0.692717, 'MQSB': 0.143342, 'MQ0F': 0.0322581, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 16], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=66058, REF=C, ALT=[T, G])
# 12
# [0, 0, 4, 8]
# {'DP': 12, 'VDB': 0.487101, 'SGB': -0.680642, 'MQSB': 0.968069, 'MQ0F': 0.166667, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 8], 'MQ': 31, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=66106, REF=A, ALT=[G])
# 40
# [0, 0, 18, 13]
# {'DP': 40, 'VDB': 8.37202e-13, 'SGB': -0.69311, 'MQSB': 0.00864477, 'MQ0F': 0.075, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 18, 13], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=66111, REF=T, ALT=[G])
# 26
# [0, 0, 15, 4]
# {'DP': 26, 'VDB': 0.027115, 'SGB': -0.69168, 'MQSB': 0.164474, 'MQ0F': 0.0769231, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 4], 'MQ': 20, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=66170, REF=T, ALT=[C, G])
# 38
# [0, 0, 31, 1]
# {'DP': 38, 'VDB': 0.153942, 'SGB': -0.69312, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 31, 1], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=70066, REF=A, ALT=[C])
# 27
# [0, 0, 17, 0]
# {'DP': 27, 'VDB': 0.0262438, 'SGB': -0.690438, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 0], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=71081, REF=A, ALT=[G, T])
# 31
# [0, 0, 4, 24]
# {'DP': 31, 'VDB': 0.470459, 'SGB': -0.693054, 'MQSB': 0.925347, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 24], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=71789, REF=C, ALT=[T, G])
# 16
# [1, 0, 13, 2]
# {'DP': 16, 'VDB': 0.00587084, 'SGB': -0.688148, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.785714, 'BQB': 1.0, 'MQ0F': 0.0625, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 13, 2], 'MQ': 34, 'FQ': -999.0, 'PV4': [1.0, 1.0, 1.0, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=71813, REF=G, ALT=[A])
# 3
# [0, 0, 1, 2]
# {'DP': 3, 'VDB': 0.0312982, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.333333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 2], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=71846, REF=T, ALT=[C])
# 35
# [0, 0, 14, 21]
# {'DP': 35, 'VDB': 0.00761487, 'SGB': -0.693136, 'MQSB': 0.350573, 'MQ0F': 0.0285714, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 14, 21], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=73674, REF=T, ALT=[C])
# 43
# [0, 0, 4, 30]
# {'DP': 43, 'VDB': 0.000479259, 'SGB': -0.693132, 'MQSB': 0.866878, 'MQ0F': 0.0465116, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 30], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=73890, REF=T, ALT=[C])
# 22
# [0, 1, 6, 10]
# {'DP': 22, 'VDB': 0.726572, 'SGB': -0.689466, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.664254, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 1, 6, 10], 'MQ': 41, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.353607, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=74019, REF=A, ALT=[G, C])
# 28
# [0, 0, 9, 17]
# {'DP': 28, 'VDB': 0.00204368, 'SGB': -0.692976, 'MQSB': 0.752257, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 17], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=74192, REF=A, ALT=[G, T])
# 8
# [0, 0, 4, 4]
# {'DP': 8, 'VDB': 0.346875, 'SGB': -0.651104, 'MQSB': 0.124046, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 4], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=74407, REF=A, ALT=[G, C])
# 24
# [0, 0, 1, 22]
# {'DP': 24, 'VDB': 0.00553345, 'SGB': -0.692717, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 22], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=74432, REF=A, ALT=[G])
# 8
# [0, 0, 1, 7]
# {'DP': 8, 'VDB': 0.360182, 'SGB': -0.651104, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 7], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=74456, REF=T, ALT=[C])
# 4
# [0, 0, 4, 0]
# {'DP': 4, 'VDB': 0.100421, 'SGB': -0.556411, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 0], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=74483, REF=C, ALT=[T, G])
# 21
# [0, 0, 7, 10]
# {'DP': 21, 'VDB': 0.00024151, 'SGB': -0.690438, 'MQSB': 0.970677, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 10], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=75090, REF=A, ALT=[T])
# 20
# [1, 0, 10, 8]
# {'DP': 20, 'VDB': 0.559746, 'SGB': -0.691153, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.395294, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 10, 8], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.409269, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=75197, REF=A, ALT=[G])
# 38
# [0, 0, 29, 9]
# {'DP': 38, 'VDB': 0.552517, 'SGB': -0.693143, 'MQSB': 0.203138, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 29, 9], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=75702, REF=T, ALT=[A])
# 19
# [0, 2, 5, 5]
# {'DP': 19, 'VDB': 0.803036, 'SGB': -0.670168, 'RPB': 0.85, 'MQB': 0.4, 'MQSB': 0.935451, 'BQB': 0.65, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 2, 5, 5], 'MQ': 40, 'FQ': -999.0, 'PV4': [0.469697, 1.0, 0.253822, 0.320419]}
# --------------------
# Record(CHROM=AF409138.1, POS=75800, REF=C, ALT=[T])
# 16
# [0, 0, 5, 11]
# ...
# --------------------
# Record(CHROM=AF409138.1, POS=135529, REF=A, ALT=[G])
# 10
# [0, 0, 7, 3]
# {'DP': 10, 'VDB': 0.192198, 'SGB': -0.670168, 'MQSB': 0.824834, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 3], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=135971, REF=G, ALT=[A])
# 10
# [0, 0, 5, 5]
# {'DP': 10, 'VDB': 0.112814, 'SGB': -0.670168, 'MQSB': 0.904729, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 5], 'MQ': 21, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=135972, REF=A, ALT=[T, G])
# 11
# [0, 0, 6, 5]
# {'DP': 11, 'VDB': 0.2216, 'SGB': -0.676189, 'MQSB': 0.742931, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 5], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136020, REF=A, ALT=[G])
# 3
# [0, 0, 3, 0]
# {'DP': 3, 'VDB': 0.235765, 'SGB': -0.511536, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 0], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136036, REF=T, ALT=[C])
# 2
# [0, 0, 0, 2]
# {'DP': 2, 'VDB': 0.22, 'SGB': -0.453602, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 2], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136089, REF=T, ALT=[C])
# 17
# [0, 0, 2, 13]
# {'DP': 17, 'VDB': 0.000438758, 'SGB': -0.688148, 'MQSB': 0.653846, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 13], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136245, REF=C, ALT=[T, G])
# 16
# [0, 0, 13, 3]
# {'DP': 16, 'VDB': 0.622694, 'SGB': -0.689466, 'MQSB': 0.99774, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 13, 3], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136350, REF=T, ALT=[C])
# 4
# [0, 0, 1, 3]
# {'DP': 4, 'VDB': 0.0277111, 'SGB': -0.556411, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 3], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136375, REF=T, ALT=[C])
# 15
# [0, 0, 5, 6]
# {'DP': 15, 'VDB': 0.0868969, 'SGB': -0.676189, 'MQSB': 0.8618, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 6], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136419, REF=A, ALT=[G])
# 13
# [0, 0, 8, 2]
# {'DP': 13, 'VDB': 0.0546694, 'SGB': -0.670168, 'MQSB': 0.25, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 2], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136441, REF=C, ALT=[T])
# 14
# [0, 0, 11, 3]
# {'DP': 14, 'VDB': 0.00204843, 'SGB': -0.686358, 'MQSB': 0.646383, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 11, 3], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136491, REF=A, ALT=[G])
# 14
# [0, 0, 1, 9]
# {'DP': 14, 'VDB': 0.00501405, 'SGB': -0.670168, 'MQSB': 1.0, 'MQ0F': 0.0714286, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 9], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136494, REF=G, ALT=[A, C, T])
# 17
# [0, 0, 1, 11]
# {'DP': 17, 'VDB': 0.00551213, 'SGB': -0.680642, 'MQSB': 1.0, 'MQ0F': 0.0588235, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 11], 'MQ': 25, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136585, REF=A, ALT=[T, G])
# 21
# [0, 0, 9, 12]
# {'DP': 21, 'VDB': 0.0475013, 'SGB': -0.692352, 'MQSB': 0.652615, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 9, 12], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136593, REF=G, ALT=[A])
# 15
# [0, 0, 4, 9]
# {'DP': 15, 'VDB': 0.896961, 'SGB': -0.683931, 'MQSB': 0.304076, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 9], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136600, REF=C, ALT=[T, G])
# 13
# [0, 0, 0, 9]
# {'DP': 13, 'VDB': 0.0308846, 'SGB': -0.662043, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 9], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136635, REF=C, ALT=[T])
# 11
# [0, 0, 1, 8]
# {'DP': 11, 'VDB': 0.000419752, 'SGB': -0.662043, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 8], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136685, REF=C, ALT=[A])
# 8
# [0, 0, 0, 5]
# {'DP': 8, 'VDB': 0.0513395, 'SGB': -0.590765, 'MQ0F': 0.375, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 5], 'MQ': 21, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136713, REF=C, ALT=[T])
# 8
# [0, 0, 1, 7]
# {'DP': 8, 'VDB': 0.00433074, 'SGB': -0.651104, 'MQSB': 1.0, 'MQ0F': 0.125, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 7], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136761, REF=G, ALT=[A])
# 11
# [0, 0, 8, 1]
# {'DP': 11, 'VDB': 0.0037412, 'SGB': -0.662043, 'MQSB': 1.0, 'MQ0F': 0.0909091, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 1], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136771, REF=C, ALT=[A])
# 6
# [0, 0, 5, 1]
# {'DP': 6, 'VDB': 0.0476592, 'SGB': -0.616816, 'MQSB': 1.0, 'MQ0F': 0.166667, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 1], 'MQ': 15, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136795, REF=T, ALT=[C])
# 1
# [0, 0, 0, 1]
# {'DP': 1, 'SGB': -0.379885, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 1], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136815, REF=T, ALT=[C])
# 1
# [0, 0, 1, 0]
# {'DP': 1, 'SGB': -0.379885, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 0], 'MQ': 40, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136836, REF=C, ALT=[A])
# 5
# [0, 0, 3, 2]
# {'DP': 5, 'VDB': 0.114666, 'SGB': -0.590765, 'MQSB': 0.333333, 'MQ0F': 0.2, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 2], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136878, REF=G, ALT=[A])
# 10
# [0, 0, 3, 2]
# {'DP': 10, 'VDB': 0.810473, 'SGB': -0.590765, 'MQSB': 0.666667, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 2], 'MQ': 16, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136884, REF=T, ALT=[A, C])
# 14
# [0, 0, 6, 7]
# {'DP': 14, 'VDB': 2.8085e-05, 'SGB': -0.683931, 'MQSB': 0.777113, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 7], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=136933, REF=A, ALT=[T])
# 16
# [1, 0, 8, 4]
# {'DP': 16, 'VDB': 0.259328, 'SGB': -0.680642, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.558035, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 8, 4], 'MQ': 35, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.193646, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=137006, REF=C, ALT=[T, A])
# 9
# [0, 0, 4, 5]
# {'DP': 9, 'VDB': 0.00127738, 'SGB': -0.662043, 'MQSB': 0.974597, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 5], 'MQ': 23, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137010, REF=G, ALT=[A])
# 8
# [0, 0, 2, 5]
# {'DP': 8, 'VDB': 0.00165115, 'SGB': -0.636426, 'MQSB': 0.6, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 5], 'MQ': 18, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137049, REF=G, ALT=[T])
# 3
# [0, 0, 2, 1]
# {'DP': 3, 'VDB': 0.0860477, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 1], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137157, REF=C, ALT=[T])
# 7
# [0, 0, 4, 2]
# {'DP': 7, 'VDB': 0.00595258, 'SGB': -0.616816, 'MQSB': 0.25, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 2], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137193, REF=G, ALT=[T])
# 28
# [0, 0, 6, 20]
# {'DP': 28, 'VDB': 0.000921754, 'SGB': -0.692976, 'MQSB': 0.210682, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 20], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137233, REF=C, ALT=[T])
# 2
# [0, 0, 1, 1]
# {'DP': 2, 'VDB': 0.38, 'SGB': -0.453602, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 1], 'MQ': 33, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137250, REF=T, ALT=[C])
# 7
# [0, 0, 5, 1]
# {'DP': 7, 'VDB': 0.19611, 'SGB': -0.616816, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 1], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137313, REF=T, ALT=[C])
# 19
# [0, 0, 11, 7]
# {'DP': 19, 'VDB': 0.911675, 'SGB': -0.691153, 'MQSB': 0.554013, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 11, 7], 'MQ': 30, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137349, REF=A, ALT=[G])
# 21
# [0, 0, 15, 2]
# {'DP': 21, 'VDB': 0.000444517, 'SGB': -0.690438, 'MQSB': 0.633333, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 2], 'MQ': 25, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137355, REF=A, ALT=[C])
# 10
# [0, 0, 10, 0]
# {'DP': 10, 'VDB': 0.00011539, 'SGB': -0.670168, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 0], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137371, REF=G, ALT=[A])
# 3
# [0, 0, 0, 2]
# {'DP': 3, 'VDB': 0.06, 'SGB': -0.453602, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 0, 2], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137376, REF=C, ALT=[T])
# 3
# [0, 0, 1, 2]
# {'DP': 3, 'VDB': 0.0983484, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 2], 'MQ': 23, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137425, REF=G, ALT=[A])
# 5
# [0, 0, 2, 1]
# {'DP': 5, 'VDB': 0.0433485, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.2, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 1], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137427, REF=T, ALT=[A])
# 5
# [0, 0, 2, 1]
# {'DP': 5, 'VDB': 0.0349627, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.2, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 1], 'MQ': 27, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137552, REF=T, ALT=[C])
# 2
# [0, 0, 2, 0]
# {'DP': 2, 'VDB': 0.28, 'SGB': -0.453602, 'MQ0F': 0.5, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 0], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137731, REF=C, ALT=[A])
# 17
# [1, 0, 15, 1]
# {'DP': 17, 'VDB': 0.42633, 'SGB': -0.689466, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 1.0, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 15, 1], 'MQ': 38, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.383367, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=137778, REF=G, ALT=[A])
# 12
# [1, 0, 8, 1]
# {'DP': 12, 'VDB': 0.00175574, 'SGB': -0.662043, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 1.0, 'BQB': 1.0, 'MQ0F': 0.0833333, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 8, 1], 'MQ': 32, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.222554, 0.461228]}
# --------------------
# Record(CHROM=AF409138.1, POS=137784, REF=A, ALT=[G])
# 7
# [0, 0, 3, 0]
# {'DP': 7, 'VDB': 0.17915, 'SGB': -0.511536, 'MQ0F': 0.142857, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 0], 'MQ': 33, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137877, REF=C, ALT=[T])
# 5
# [0, 0, 1, 4]
# {'DP': 5, 'VDB': 0.0148128, 'SGB': -0.590765, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 1, 4], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137885, REF=A, ALT=[G])
# 11
# [0, 0, 3, 6]
# {'DP': 11, 'VDB': 0.00129813, 'SGB': -0.662043, 'MQSB': 0.231146, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 6], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137931, REF=G, ALT=[A])
# 10
# [0, 0, 6, 4]
# {'DP': 10, 'VDB': 0.560195, 'SGB': -0.670168, 'MQSB': 0.167959, 'MQ0F': 0.1, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 4], 'MQ': 28, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137935, REF=C, ALT=[T, G])
# 16
# [0, 0, 7, 7]
# {'DP': 16, 'VDB': 0.993788, 'SGB': -0.686358, 'MQSB': 0.194346, 'MQ0F': 0.0625, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 7], 'MQ': 32, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137964, REF=T, ALT=[C])
# 27
# [0, 0, 6, 20]
# {'DP': 27, 'VDB': 1.05423e-05, 'SGB': -0.692976, 'MQSB': 0.874768, 'MQ0F': 0.037037, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 20], 'MQ': 20, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137967, REF=C, ALT=[T])
# 34
# [0, 0, 8, 21]
# {'DP': 34, 'VDB': 0.000164847, 'SGB': -0.693079, 'MQSB': 0.995249, 'MQ0F': 0.0294118, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 21], 'MQ': 22, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=137997, REF=C, ALT=[T, A])
# 16
# [0, 0, 6, 9]
# {'DP': 16, 'VDB': 0.00323625, 'SGB': -0.688148, 'MQSB': 0.534333, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 9], 'MQ': 26, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=138088, REF=C, ALT=[A, T])
# 22
# [0, 0, 2, 20]
# {'DP': 22, 'VDB': 0.00146879, 'SGB': -0.692562, 'MQSB': 0.775, 'MQ0F': 0.181818, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 20], 'MQ': 24, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=140522, REF=T, ALT=[C])
# 26
# [0, 0, 5, 20]
# {'DP': 26, 'VDB': 0.371351, 'SGB': -0.692914, 'MQSB': 0.829508, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 5, 20], 'MQ': 38, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=140657, REF=T, ALT=[C])
# 14
# [0, 0, 4, 10]
# {'DP': 14, 'VDB': 0.00268477, 'SGB': -0.686358, 'MQSB': 0.960789, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 10], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=140669, REF=T, ALT=[C])
# 5
# [0, 0, 2, 1]
# {'DP': 5, 'VDB': 0.121629, 'SGB': -0.511536, 'MQSB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 1], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=140855, REF=G, ALT=[A, T])
# 23
# [1, 0, 11, 4]
# {'DP': 23, 'VDB': 0.010128, 'SGB': -0.688148, 'RPB': 1.0, 'MQB': 1.0, 'MQSB': 0.983592, 'BQB': 1.0, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [1, 0, 11, 4], 'MQ': 39, 'FQ': -999.0, 'PV4': [1.0, 1.0, 0.309469, 1.0]}
# --------------------
# Record(CHROM=AF409138.1, POS=140972, REF=G, ALT=[A])
# 27
# [0, 0, 11, 15]
# {'DP': 27, 'VDB': 0.249453, 'SGB': -0.692976, 'MQSB': 0.115917, 'MQ0F': 0.037037, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 11, 15], 'MQ': 35, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=141089, REF=A, ALT=[G])
# 23
# [0, 0, 17, 6]
# {'DP': 23, 'VDB': 0.566319, 'SGB': -0.692717, 'MQSB': 0.432208, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 17, 6], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=141116, REF=A, ALT=[G])
# 33
# [0, 0, 15, 14]
# {'DP': 33, 'VDB': 0.64279, 'SGB': -0.693079, 'MQSB': 0.525288, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 15, 14], 'MQ': 34, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=141542, REF=C, ALT=[T])
# 16
# [0, 0, 2, 14]
# {'DP': 16, 'VDB': 0.54149, 'SGB': -0.689466, 'MQSB': 0.857143, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 2, 14], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=141665, REF=T, ALT=[C, G])
# 30
# [0, 0, 8, 18]
# {'DP': 30, 'VDB': 8.80668e-05, 'SGB': -0.692976, 'MQSB': 0.954391, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 8, 18], 'MQ': 41, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=141755, REF=A, ALT=[G])
# 13
# [0, 0, 7, 4]
# {'DP': 13, 'VDB': 0.214515, 'SGB': -0.676189, 'MQSB': 0.562708, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 7, 4], 'MQ': 37, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=144942, REF=C, ALT=[T, A, G])
# 32
# [0, 0, 6, 21]
# {'DP': 32, 'VDB': 0.400081, 'SGB': -0.693021, 'MQSB': 0.276336, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 6, 21], 'MQ': 39, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=145147, REF=G, ALT=[C])
# 9
# [0, 0, 4, 4]
# {'DP': 9, 'VDB': 0.327269, 'SGB': -0.651104, 'MQSB': 0.248092, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 4, 4], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=145173, REF=A, ALT=[G])
# 17
# [0, 0, 3, 11]
# {'DP': 17, 'VDB': 0.392815, 'SGB': -0.686358, 'MQSB': 0.12893, 'MQ0F': 0.0, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 3, 11], 'MQ': 36, 'FQ': -999.0}
# --------------------
# Record(CHROM=AF409138.1, POS=150349, REF=G, ALT=[A])
# 29
# [0, 0, 10, 17]
# {'DP': 29, 'VDB': 0.00241937, 'SGB': -0.693021, 'MQSB': 0.709516, 'MQ0F': 0.206897, 'AF1': 1.0, 'AC1': 1.0, 'DP4': [0, 0, 10, 17], 'MQ': 1, 'FQ': -999.0}
# --------------------
# 538

# %% [markdown]
# #### total number of SNPs in vcf :

# %%
vcf_reader = vcf.Reader(open('./samtools_out/saratov_vars.vcf', 'r'))
counter = 0
for record in vcf_reader:
    if "INDEL" not in record.INFO.keys():
        counter += 1

print("total SNPs : ", counter)
# Out:
# total SNPs :  520

# %% [markdown]
# ####  DP4 contains 4 values:
# 1. forward ref alleles
# 2. reverse ref
# 3. forward non-ref
# 4. reverse non-ref alleles
#
# Sum can be smaller than DP (The number of reads covering or bridging POS)  because low-quality bases are not counted.
#
# #### SNPs with coverage more than 10:

# %%
vcf_reader = vcf.Reader(open('./samtools_out/saratov_vars.vcf', 'r'))
counter = 0
for record in vcf_reader:
    if "INDEL" not in record.INFO.keys():
        if record.INFO["DP4"][2] + record.INFO["DP4"][3] >= 10:
            counter += 1
print("SNP passing filter: ", counter)
# Out:
# SNP passing filter:  388

# %% [markdown]
# #### 8. consensus calling
# - to create consensus we apply variants to the reference
#
# #### NOTE : if we want to get consensus, we'll have to redo the calling step, as bcftools can apply only files compressed with bgzip to the reference. If we want just to get vcf file, we don't need this step
#
# the command `-Oz -o` means ouput in bzip format
# - we need this compressed format to get consensus (otherwise it doesn't work)
# - then we must index compressed `vcf` file, we need it derive consensus as well

# %%
# %%bash
# bcftools call \
# --consensus-caller \
# --variants-only \
# --skip-variants indels \
# --ploidy-file ./samtools_out/ploid.txt \
# ./samtools_out/saratov_vars.bcf \
# -Oz -o ./samtools_out/saratov_vars.vcf.gz \

# %% [markdown]
# #### we must index the `lsd_2_vars.vcf.gz`

# %%
# %%bash
# bcftools tabix -p vcf ./samtools_out/saratov_vars.vcf.gz

# %% [markdown]
# #### creating consensus

# %% [markdown]
# Create consensus sequence by applying VCF variants to a reference fasta file.
#
# - reference sequence
# - `bcf` file with variants calls
# - indexed `vcf` file
#
# but:
# - we didn't call indels, so we don't need to normalize and filter indels
#
# see : http://samtools.github.io/bcftools/howtos/consensus-sequence.html

# %%
# %%bash
# ls -l ./input_data
# Out:
# total 446644
# -rwxrwxrwx 1 root root  33407745 Feb 15 10:45 1_trim_crop_and_trail_32_1P.fastq
# -rwxrwxrwx 1 root root   1921926 Feb 15 10:45 1_trim_crop_and_trail_32_1U.fastq
# -rwxrwxrwx 1 root root  33002253 Feb 15 10:45 1_trim_crop_and_trail_32_2P.fastq
# -rwxrwxrwx 1 root root    186221 Feb 15 10:45 1_trim_crop_and_trail_32_2U.fastq
# -rwxrwxrwx 1 root root  26364751 Feb 18 10:44 2_trim_crop_and_trail_32_2P.fastq
# -rwxrwxrwx 1 root root 133352346 Jun 25  2018 SUD-Saratov_S1_L001_R1_001.fastq
# -rwxrwxrwx 1 root root 138569286 Jun 25  2018 SUD-Saratov_S1_L001_R2_001.fastq
# -rwxrwxrwx 1 root root  88870486 Feb 18 12:59 input_data.rar
# -rwxrwxrwx 1 root root   1363903 Feb 14 16:47 merged_document.aln
# -rwxrwxrwx 1 root root    152749 Jun 25  2018 ref_AF409138.1.fasta
# -rwxrwxrwx 1 root root        27 Feb 14 17:40 ref_AF409138.1.fasta.fai
# -rwxrwxrwx 1 root root    150532 Feb 14 16:43 saratov_map_on_AF_consensus.fa

# %%
# %%bash
# cat ./input_data/ref_AF409138.1.fasta | \
# bcftools consensus \
# ./samtools_out/saratov_vars.vcf.gz \
# > ./samtools_out/consensus_seq_.fasta
# Out:
# Note: the --sample option not given, applying all records
